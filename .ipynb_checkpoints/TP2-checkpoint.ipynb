# %% [markdown]
# # Partie 1 - Les données

# %% [markdown]
# ### 1. Importer les données et visualiser les premières observations :

# %%
import pandas as pd

train = pd.read_csv('titanic_train.csv', sep=',')
train.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %% [markdown]
# ### 2. Indexer les données :

# %%
train.set_index("PassengerId", inplace=True, drop=True)

# %% [markdown]
# ### 3. Observer les noms des variables à l’aide train.columns et faire le bilan de celles-ci à l’aide des informations disponibles sur le web.

# %%
train.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
import seaborn as sn

sn.heatmap(train.corr(), cmap="PiYG", vmax=1.0, vmin=-1.0)
# Out:
# /tmp/ipykernel_12212/2479090422.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sn.heatmap(train.corr(), cmap="PiYG", vmax=1.0, vmin=-1.0)
# <AxesSubplot: >

# %% [markdown]
# - `Survived` : boolean pour savoir si le passager à survécu ou non (0 = mort, et 1 = survive)
# - `Pclass` : Formule ( 1 = Premier classe, 2 = Seconde classe, et 3 = Troisième classe )
# - `Name` : Nom du passager
# - `Sex` : Sex du passager
# - `Age` : Age du passager
# - `SibSp` : Nombre de frères/sœurs/conjoints qui est abord du Titanic
# - `Parch` : Nombre de parents/enfants qui est abord du Titanic
# - `Ticket` : Numéro de ticket
# - `Fare` : Tarif
# - `Cabin` : Numéro de Cabine
# - `Embarked` : Port d'embarquement (C = Cherbourg, Q = Queenstown, S = Southampton)

# %% [markdown]
# # Partie 2 - Première modèle de niveau 0

# %% [markdown]
# ### 1. Filtrer et construire les données du modèle 0

# %%
def parse_model_0(X):
    target = X.Survived
    X = X[["Fare", "SibSp", "Parch"]]
    return X, target


X, y = parse_model_0(train.copy())

# %%
train.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %% [markdown]
# On utilise la validation croisée, car on essaye de compenser le faire de ne pas avoir un gros échantillon pour la
# phase d'apprentissage.
#
# On note que l'on dispose de 342 personnes qui ont survécu contre 549. On peut donc dire que l'échantillon est équilibré,
# on n'a pas classe qui est fortement majoritaire au détriment de l'autre.

# %%
import numpy as np
from sklearn.model_selection import cross_val_score


def compute_score(clf, X, y):
    xval = cross_val_score(clf, X, y, cv=5)
    return np.mean(xval)

# %% [markdown]
# ### 3. Calculer le modèle de régression logistique.

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()
lr.fit(X, y)

compute_score(lr, X, y)
# Out:
# 0.6746092524009792

# %% [markdown]
# # Partie 3 - Deuxième modèle

# %% [markdown]
# ### 1. Diviser la population en deux sous-populations en fonction de la variable à prédire

# %%
survived = train.copy()[train.Survived == 1]
dead = train.copy()[train.Survived == 0]

# %% [markdown]
# ### 2. Tracer l’histogramme de la distribution des survivants et des victimes pour la variable Pclass

# %%
import matplotlib.pyplot as plt


def plot_hist(feature, bins=20):
    x1 = dead[feature].dropna()
    x2 = survived[feature].dropna()
    plt.hist([x1, x2], label=["Victime", "Survivant"], bins=bins)  #, color = [’’, ’b’]
    plt.legend(loc="upper left")
    plt.title("distribution relative de %s" % feature)
    plt.show()


plot_hist("Pclass")

# %% [markdown]
# ### 3. La variable Pclass est-elle importante ? Pourquoi ?

# %% [markdown]
# On remarque que la propriété de la troisième classe à une grosse importante par rapport à l'information de la seconde ou la première classe. Car pour la 1er et 2nd classe on note environ 50% de survivants et 50% de victimes, alors que pour la troisième classe, on observe un grand nombre de victimes. On peut donc en conclure que la propriété de la classe est important particulièrement dans le cas de la troisième classe.

# %% [markdown]
# ### 4. La variable catégorielle Pclass a peu de modalité, on peut donc créer une variable ’dummy’ pour chaque modalité. Transformer la variable catégorielle Pclass en variable dummy et créer le nouveau jeu de donnée pour le modèle 1

# %%
def parse_model_1(X):
    target = X.Survived
    class_dummies = pd.get_dummies(X["Pclass"], prefix="split_Pclass")
    X = X.join(class_dummies)
    to_del = ["Name", "Age", "Cabin", "Embarked", "Survived", "Ticket", "Sex", "Pclass"]
    for col in to_del:
        del X[col]
    return X, target

# %% [markdown]
# ### 5. Calculer le modèle de régression logistique. Commenter

# %%
X, y = parse_model_1(train.copy())

lr.fit(X, y)
compute_score(lr, X, y)
# Out:
# /home/ludwig/Documents/ULCO/M2/IA - Verel/TPS/Tp2/venv/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.6937040989266211

# %% [markdown]
# On note qu'avec l'information de la classe, on obtient un meilleur score. Cela s'expliquer par le fait que cette nouvelle propriété permet une meilleure généralisation.

# %% [markdown]
# ### 6. Tracer les coefficients de la régression logistique et donner une interprétation ceux-ci :

# %%
def plot_lr_coefs(X, lr):
    fig, ax = plt.subplots()
    xlabels = X.columns.values.tolist()
    yvalues = lr.coef_[0,]
    index = np.arange(len(yvalues))
    bar_width = 0.35
    opacity = 0.4
    rects = plt.bar(index, yvalues,
                    bar_width, alpha=opacity,
                    color="b", label="")
    plt.ylabel("Valeur")
    plt.title("Poids des variables")
    plt.xticks(index, xlabels, rotation=40)
    plt.legend()
    plt.tight_layout()
    plt.show()


plot_lr_coefs(X, lr)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# Cela confirme la précédente hypothèse, car on note que l'information ce la troisième classe à une
# influence négativement sur le fait de survivre.

# %% [markdown]
# # Partie 4 - Troisiéme modéle

# %% [markdown]
# ### 1. Créer le nouveau jeu de donnée en utilisant la méthode fillna pour les valeurs manquantes.

# %%
def parse_model_2(X):
    X.Age = X.Age.fillna(np.nanmedian(X["Age"]))

    target = X.Survived

    class_dummies = pd.get_dummies(X["Pclass"], prefix="split_Pclass")
    X = X.join(class_dummies)

    class_dummies = pd.get_dummies(X["Sex"], prefix="split_sex")
    X = X.join(class_dummies)

    to_del = ["Name", "Cabin", "Embarked", "Survived", "Ticket", "Sex", "Pclass"]
    for col in to_del:
        del X[col]
    return X, target

# %% [markdown]
# ### 2. Calculer la régression logistique

# %%
X, y = parse_model_2(train.copy())

lr = LogisticRegression()
lr.fit(X, y)

compute_score(lr, X, y)
# Out:
# /home/ludwig/Documents/ULCO/M2/IA - Verel/TPS/Tp2/venv/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/ludwig/Documents/ULCO/M2/IA - Verel/TPS/Tp2/venv/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/ludwig/Documents/ULCO/M2/IA - Verel/TPS/Tp2/venv/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/ludwig/Documents/ULCO/M2/IA - Verel/TPS/Tp2/venv/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/ludwig/Documents/ULCO/M2/IA - Verel/TPS/Tp2/venv/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/ludwig/Documents/ULCO/M2/IA - Verel/TPS/Tp2/venv/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7867553825874083

# %% [markdown]
# ### 3. Les nouvelles variables créées sont-elles importantes dans la régression obtenue ?

# %%
plot_lr_coefs(X, lr)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# On note que l'information sur le sex à une très forte influence. On constate que le fait d'être une femme donne une plus grande chance survie contrairement au fait d'être un homme. On note également que grâce à cette nouvelle information, l'importance de la 1er classe augmente contrairement à celle de la 3ème classe qui elle diminue.

# %% [markdown]
# ### 4. Tracer les histogrammes des survivants et des victimes pour la variable Age. Commenter.

# %%
plot_hist("Age")

# %% [markdown]
# On observe que la probabilité de survivre est plus forte avec un âge compris entre 0 et 10ans. Alors qu'à l'inverse, il y a plus de chance de mourir lorsque l'on a entre 20 et 45 ans. Après cet âge, on a une probabilité de survivre d'environ 50%. On peut donc en déduire que l'introduction de cette nouvelle propriété va pouvoir améliorer le modèle.

# %% [markdown]
# ### 5. Créer la variable non-linéaire is child

# %%
X["is_child"] = X.Age < 8

# %% [markdown]
# ### 6. Calculer le modèle de régression logistique. Commenter.

# %%
lr = LogisticRegression()
lr.fit(X, y)

compute_score(lr, X, y)
# Out:
# /home/ludwig/Documents/ULCO/M2/IA - Verel/TPS/Tp2/venv/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/ludwig/Documents/ULCO/M2/IA - Verel/TPS/Tp2/venv/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/ludwig/Documents/ULCO/M2/IA - Verel/TPS/Tp2/venv/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/ludwig/Documents/ULCO/M2/IA - Verel/TPS/Tp2/venv/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/ludwig/Documents/ULCO/M2/IA - Verel/TPS/Tp2/venv/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/ludwig/Documents/ULCO/M2/IA - Verel/TPS/Tp2/venv/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7968489109283786

# %%
plot_lr_coefs(X, lr)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# Cela confirme l'hypothèse précédente, car on obtient un meilleur score. Cela peut également se vérifier un traçant les coefficients de la régression logistique, on note en effect que le fait d'être considéré comme un enfant à une très grande importance dans le fait de survivre ou non.

# %% [markdown]
# # Partie 5 -  Selection de variable

# %% [markdown]
# ### 1. En considérant les variables vu jusqu’à présent, quel est le meilleur modèle logistique ayant 2, 3 et 4 variables ?

# %%
columns = ['Age', 'SibSp', 'Parch', 'Fare', 'split_Pclass_1', 'split_Pclass_2',
           'split_Pclass_3', 'split_sex_female', 'split_sex_male', 'is_child']


def parse_model_3(X, keepColumns):
    X.Age = X.Age.fillna(np.nanmedian(X["Age"]))
    target = X.Survived

    class_dummies = pd.get_dummies(X["Pclass"], prefix="split_Pclass")
    X = X.join(class_dummies)

    class_dummies = pd.get_dummies(X["Sex"], prefix="split_sex")
    X = X.join(class_dummies)

    X["is_child"] = X.Age < 8

    to_del = [x for x in X.columns if x not in keepColumns]
    for col in to_del:
        del X[col]
    return X, target


def test_with_variables(nbVariables: int, columns, train, keepColumns=[]):
    if len(keepColumns) >= nbVariables:
        X, y = parse_model_3(train.copy(), keepColumns)

        lr = LogisticRegression(max_iter=1000000)
        lr.fit(X, y)

        score = compute_score(lr, X, y)

        print(str(score) + " : ", keepColumns)

        return (score, keepColumns)

    hightestScore = (0, [])

    for colX in columns:
        if colX not in keepColumns:
            score = test_with_variables(nbVariables, columns, train, keepColumns + [colX])

            if score[0] > hightestScore[0]:
                hightestScore = score

    return hightestScore


with_1_vars = test_with_variables(1, columns, train.copy())
with_2_vars = test_with_variables(2, columns, train.copy())
with_3_vars = test_with_variables(3, columns, train.copy())
with_4_vars = test_with_variables(4, columns, train.copy())
#
print("#####")
print("Avec 1 variable : ", with_1_vars)
print("Avec 2 variables : ", with_2_vars)
print("Avec 3 variables : ", with_3_vars)
print("Avec 4 variables : ", with_4_vars)
#1 - brute force
#2 - binariser toute les variables
#3 - On fait comme pour Pclass pour toute les valeurs => One Hot Enconding
#4 -

train.columns
# Out:
# 0.6161634548992531 :  ['Age']
# 0.6161634548992531 :  ['SibSp']
# 0.6071872449940369 :  ['Parch']
# 0.6645031699202812 :  ['Fare']
# 0.6790973573535873 :  ['split_Pclass_1']
# 0.6026803088318372 :  ['split_Pclass_2']
# 0.66784884815768 :  ['split_Pclass_3']
# 0.7867365513778168 :  ['split_sex_female']
# 0.7867365513778168 :  ['split_sex_male']
# 0.6363756198606489 :  ['is_child']
# 0.6184106459104889 :  ['Age', 'SibSp']
# 0.607180967924173 :  ['Age', 'Parch']
# 0.6599962337580817 :  ['Age', 'Fare']
# 0.6824681438704412 :  ['Age', 'split_Pclass_1']
# 0.6183792605611701 :  ['Age', 'split_Pclass_2']
# 0.6689473353838429 :  ['Age', 'split_Pclass_3']
# 0.7867365513778168 :  ['Age', 'split_sex_female']
# 0.7867365513778168 :  ['Age', 'split_sex_male']
# 0.6363756198606489 :  ['Age', 'is_child']
# 0.6184106459104889 :  ['SibSp', 'Age']
# 0.619534241416107 :  ['SibSp', 'Parch']
# 0.6779863159876969 :  ['SibSp', 'Fare']
# 0.6790973573535873 :  ['SibSp', 'split_Pclass_1']
# 0.6060510953486912 :  ['SibSp', 'split_Pclass_2']
# 0.66784884815768 :  ['SibSp', 'split_Pclass_3']
# 0.7889837423890528 :  ['SibSp', 'split_sex_female']
# 0.7889837423890528 :  ['SibSp', 'split_sex_male']
# 0.6363756198606489 :  ['SibSp', 'is_child']
# 0.607180967924173 :  ['Parch', 'Age']
# 0.619534241416107 :  ['Parch', 'SibSp']
# 0.6644968928504174 :  ['Parch', 'Fare']
# 0.6723620613897432 :  ['Parch', 'split_Pclass_1']
# 0.6318937919779047 :  ['Parch', 'split_Pclass_2']
# 0.664478061640826 :  ['Parch', 'split_Pclass_3']
# 0.7867365513778168 :  ['Parch', 'split_sex_female']
# 0.7867365513778168 :  ['Parch', 'split_sex_male']
# 0.6307639194024229 :  ['Parch', 'is_child']
# 0.6599962337580817 :  ['Fare', 'Age']
# 0.6779863159876969 :  ['Fare', 'SibSp']
# 0.6644968928504174 :  ['Fare', 'Parch']
# 0.6824681438704413 :  ['Fare', 'split_Pclass_1']
# 0.6768501663423514 :  ['Fare', 'split_Pclass_2']
# 0.6757265708367335 :  ['Fare', 'split_Pclass_3']
# 0.7822547234950725 :  ['Fare', 'split_sex_female']
# 0.7822547234950725 :  ['Fare', 'split_sex_male']
# 0.6869688029627771 :  ['Fare', 'is_child']
# 0.6824681438704412 :  ['split_Pclass_1', 'Age']
# 0.6790973573535873 :  ['split_Pclass_1', 'SibSp']
# 0.6723620613897432 :  ['split_Pclass_1', 'Parch']
# 0.6824681438704413 :  ['split_Pclass_1', 'Fare']
# 0.6790973573535873 :  ['split_Pclass_1', 'split_Pclass_2']
# 0.6656142112861716 :  ['split_Pclass_1', 'split_Pclass_3']
# 0.7867365513778168 :  ['split_Pclass_1', 'split_sex_female']
# 0.7867365513778168 :  ['split_Pclass_1', 'split_sex_male']
# 0.6981859268093654 :  ['split_Pclass_1', 'is_child']
# 0.6183792605611701 :  ['split_Pclass_2', 'Age']
# 0.6060510953486912 :  ['split_Pclass_2', 'SibSp']
# 0.6318937919779047 :  ['split_Pclass_2', 'Parch']
# 0.6768501663423514 :  ['split_Pclass_2', 'Fare']
# 0.6790973573535873 :  ['split_Pclass_2', 'split_Pclass_1']
# 0.6656142112861716 :  ['split_Pclass_2', 'split_Pclass_3']
# 0.7867365513778168 :  ['split_Pclass_2', 'split_sex_female']
# 0.7867365513778168 :  ['split_Pclass_2', 'split_sex_male']
# 0.6363756198606489 :  ['split_Pclass_2', 'is_child']
# 0.6689473353838429 :  ['split_Pclass_3', 'Age']
# 0.66784884815768 :  ['split_Pclass_3', 'SibSp']
# 0.664478061640826 :  ['split_Pclass_3', 'Parch']
# 0.6757265708367335 :  ['split_Pclass_3', 'Fare']
# 0.6656142112861716 :  ['split_Pclass_3', 'split_Pclass_1']
# 0.6656142112861716 :  ['split_Pclass_3', 'split_Pclass_2']
# 0.7867365513778168 :  ['split_Pclass_3', 'split_sex_female']
# 0.7867365513778168 :  ['split_Pclass_3', 'split_sex_male']
# 0.6701148703785073 :  ['split_Pclass_3', 'is_child']
# 0.7867365513778168 :  ['split_sex_female', 'Age']
# 0.7889837423890528 :  ['split_sex_female', 'SibSp']
# 0.7867365513778168 :  ['split_sex_female', 'Parch']
# 0.7822547234950725 :  ['split_sex_female', 'Fare']
# 0.7867365513778168 :  ['split_sex_female', 'split_Pclass_1']
# 0.7867365513778168 :  ['split_sex_female', 'split_Pclass_2']
# 0.7867365513778168 :  ['split_sex_female', 'split_Pclass_3']
# 0.7867365513778168 :  ['split_sex_female', 'split_sex_male']
# 0.7867365513778168 :  ['split_sex_female', 'is_child']
# 0.7867365513778168 :  ['split_sex_male', 'Age']
# 0.7889837423890528 :  ['split_sex_male', 'SibSp']
# 0.7867365513778168 :  ['split_sex_male', 'Parch']
# 0.7822547234950725 :  ['split_sex_male', 'Fare']
# 0.7867365513778168 :  ['split_sex_male', 'split_Pclass_1']
# 0.7867365513778168 :  ['split_sex_male', 'split_Pclass_2']
# 0.7867365513778168 :  ['split_sex_male', 'split_Pclass_3']
# 0.7867365513778168 :  ['split_sex_male', 'split_sex_female']
# 0.7867365513778168 :  ['split_sex_male', 'is_child']
# 0.6363756198606489 :  ['is_child', 'Age']
# 0.6363756198606489 :  ['is_child', 'SibSp']
# 0.6307639194024229 :  ['is_child', 'Parch']
# 0.6869688029627771 :  ['is_child', 'Fare']
# 0.6981859268093654 :  ['is_child', 'split_Pclass_1']
# 0.6363756198606489 :  ['is_child', 'split_Pclass_2']
# 0.6701148703785073 :  ['is_child', 'split_Pclass_3']
# 0.7867365513778168 :  ['is_child', 'split_sex_female']
# 0.7867365513778168 :  ['is_child', 'split_sex_male']
# 0.636375619860649 :  ['Age', 'SibSp', 'Parch']
# 0.6846839495323582 :  ['Age', 'SibSp', 'Fare']
# 0.6858389303872953 :  ['Age', 'SibSp', 'split_Pclass_1']
# 0.6239972380892599 :  ['Age', 'SibSp', 'split_Pclass_2']
# 0.6723118448308328 :  ['Age', 'SibSp', 'split_Pclass_3']
# 0.7889837423890528 :  ['Age', 'SibSp', 'split_sex_female']
# 0.7889837423890528 :  ['Age', 'SibSp', 'split_sex_male']
# 0.6363756198606489 :  ['Age', 'SibSp', 'is_child']
# 0.636375619860649 :  ['Age', 'Parch', 'SibSp']
# 0.6633670202749355 :  ['Age', 'Parch', 'Fare']
# 0.6891971627644216 :  ['Age', 'Parch', 'split_Pclass_1']
# 0.6318875149080408 :  ['Age', 'Parch', 'split_Pclass_2']
# 0.679047140794677 :  ['Age', 'Parch', 'split_Pclass_3']
# 0.7867365513778168 :  ['Age', 'Parch', 'split_sex_female']
# 0.7867365513778168 :  ['Age', 'Parch', 'split_sex_male']
# 0.6307639194024229 :  ['Age', 'Parch', 'is_child']
# 0.6846839495323582 :  ['Age', 'Fare', 'SibSp']
# 0.6633670202749355 :  ['Age', 'Fare', 'Parch']
# 0.6790910802837236 :  ['Age', 'Fare', 'split_Pclass_1']
# 0.680202121649614 :  ['Age', 'Fare', 'split_Pclass_2']
# 0.6813068859456406 :  ['Age', 'Fare', 'split_Pclass_3']
# 0.7822547234950725 :  ['Age', 'Fare', 'split_sex_female']
# 0.7822547234950725 :  ['Age', 'Fare', 'split_sex_male']
# 0.6847027807419497 :  ['Age', 'Fare', 'is_child']
# 0.6858389303872953 :  ['Age', 'split_Pclass_1', 'SibSp']
# 0.6891971627644216 :  ['Age', 'split_Pclass_1', 'Parch']
# 0.6790910802837236 :  ['Age', 'split_Pclass_1', 'Fare']
# 0.6869436946833218 :  ['Age', 'split_Pclass_1', 'split_Pclass_2']
# 0.6835791852363317 :  ['Age', 'split_Pclass_1', 'split_Pclass_3']
# 0.7822735547046639 :  ['Age', 'split_Pclass_1', 'split_sex_female']
# 0.7822735547046639 :  ['Age', 'split_Pclass_1', 'split_sex_male']
# 0.7026740317619734 :  ['Age', 'split_Pclass_1', 'is_child']
# 0.6239972380892599 :  ['Age', 'split_Pclass_2', 'SibSp']
# 0.6318875149080408 :  ['Age', 'split_Pclass_2', 'Parch']
# 0.680202121649614 :  ['Age', 'split_Pclass_2', 'Fare']
# 0.6869436946833218 :  ['Age', 'split_Pclass_2', 'split_Pclass_1']
# 0.6779486535685143 :  ['Age', 'split_Pclass_2', 'split_Pclass_3']
# 0.7867365513778168 :  ['Age', 'split_Pclass_2', 'split_sex_female']
# 0.7867365513778168 :  ['Age', 'split_Pclass_2', 'split_sex_male']
# 0.6363756198606489 :  ['Age', 'split_Pclass_2', 'is_child']
# 0.6723118448308328 :  ['Age', 'split_Pclass_3', 'SibSp']
# 0.679047140794677 :  ['Age', 'split_Pclass_3', 'Parch']
# 0.6813068859456406 :  ['Age', 'split_Pclass_3', 'Fare']
# 0.6835791852363317 :  ['Age', 'split_Pclass_3', 'split_Pclass_1']
# 0.6779486535685143 :  ['Age', 'split_Pclass_3', 'split_Pclass_2']
# 0.8024355031071495 :  ['Age', 'split_Pclass_3', 'split_sex_female']
# 0.8024355031071495 :  ['Age', 'split_Pclass_3', 'split_sex_male']
# 0.6723306760404244 :  ['Age', 'split_Pclass_3', 'is_child']
# 0.7889837423890528 :  ['Age', 'split_sex_female', 'SibSp']
# 0.7867365513778168 :  ['Age', 'split_sex_female', 'Parch']
# 0.7822547234950725 :  ['Age', 'split_sex_female', 'Fare']
# 0.7822735547046639 :  ['Age', 'split_sex_female', 'split_Pclass_1']
# 0.7867365513778168 :  ['Age', 'split_sex_female', 'split_Pclass_2']
# 0.8024355031071495 :  ['Age', 'split_sex_female', 'split_Pclass_3']
# 0.7867365513778168 :  ['Age', 'split_sex_female', 'split_sex_male']
# 0.7867365513778168 :  ['Age', 'split_sex_female', 'is_child']
# 0.7889837423890528 :  ['Age', 'split_sex_male', 'SibSp']
# 0.7867365513778168 :  ['Age', 'split_sex_male', 'Parch']
# 0.7822547234950725 :  ['Age', 'split_sex_male', 'Fare']
# 0.7822735547046639 :  ['Age', 'split_sex_male', 'split_Pclass_1']
# 0.7867365513778168 :  ['Age', 'split_sex_male', 'split_Pclass_2']
# 0.8024355031071495 :  ['Age', 'split_sex_male', 'split_Pclass_3']
# 0.7867365513778168 :  ['Age', 'split_sex_male', 'split_sex_female']
# 0.7867365513778168 :  ['Age', 'split_sex_male', 'is_child']
# 0.6363756198606489 :  ['Age', 'is_child', 'SibSp']
# 0.6307639194024229 :  ['Age', 'is_child', 'Parch']
# 0.6847027807419497 :  ['Age', 'is_child', 'Fare']
# 0.7026740317619734 :  ['Age', 'is_child', 'split_Pclass_1']
# 0.6363756198606489 :  ['Age', 'is_child', 'split_Pclass_2']
# 0.6723306760404244 :  ['Age', 'is_child', 'split_Pclass_3']
# 0.7867365513778168 :  ['Age', 'is_child', 'split_sex_female']
# 0.7867365513778168 :  ['Age', 'is_child', 'split_sex_male']
# 0.636375619860649 :  ['SibSp', 'Age', 'Parch']
# 0.6846839495323582 :  ['SibSp', 'Age', 'Fare']
# 0.6858389303872953 :  ['SibSp', 'Age', 'split_Pclass_1']
# 0.6239972380892599 :  ['SibSp', 'Age', 'split_Pclass_2']
# 0.6723118448308328 :  ['SibSp', 'Age', 'split_Pclass_3']
# 0.7889837423890528 :  ['SibSp', 'Age', 'split_sex_female']
# 0.7889837423890528 :  ['SibSp', 'Age', 'split_sex_male']
# 0.6363756198606489 :  ['SibSp', 'Age', 'is_child']
# 0.636375619860649 :  ['SibSp', 'Parch', 'Age']
# 0.6746092524009792 :  ['SibSp', 'Parch', 'Fare']
# 0.6689912748728892 :  ['SibSp', 'Parch', 'split_Pclass_1']
# 0.6329985562739313 :  ['SibSp', 'Parch', 'split_Pclass_2']
# 0.6532421065846463 :  ['SibSp', 'Parch', 'split_Pclass_3']
# 0.7889837423890528 :  ['SibSp', 'Parch', 'split_sex_female']
# 0.7889837423890528 :  ['SibSp', 'Parch', 'split_sex_male']
# 0.6307701964722867 :  ['SibSp', 'Parch', 'is_child']
# 0.6846839495323582 :  ['SibSp', 'Fare', 'Age']
# 0.6746092524009792 :  ['SibSp', 'Fare', 'Parch']
# 0.6824681438704413 :  ['SibSp', 'Fare', 'split_Pclass_1']
# 0.6835917393760592 :  ['SibSp', 'Fare', 'split_Pclass_2']
# 0.6656330424957629 :  ['SibSp', 'Fare', 'split_Pclass_3']
# 0.7912372104701525 :  ['SibSp', 'Fare', 'split_sex_female']
# 0.7912372104701525 :  ['SibSp', 'Fare', 'split_sex_male']
# 0.7038039043374553 :  ['SibSp', 'Fare', 'is_child']
# 0.6858389303872953 :  ['SibSp', 'split_Pclass_1', 'Age']
# 0.6689912748728892 :  ['SibSp', 'split_Pclass_1', 'Parch']
# 0.6824681438704413 :  ['SibSp', 'split_Pclass_1', 'Fare']
# 0.6689849978030256 :  ['SibSp', 'split_Pclass_1', 'split_Pclass_2']
# 0.6689849978030256 :  ['SibSp', 'split_Pclass_1', 'split_Pclass_3']
# 0.7945954428472789 :  ['SibSp', 'split_Pclass_1', 'split_sex_female']
# 0.7945954428472789 :  ['SibSp', 'split_Pclass_1', 'split_sex_male']
# 0.6993095223149834 :  ['SibSp', 'split_Pclass_1', 'is_child']
# 0.6239972380892599 :  ['SibSp', 'split_Pclass_2', 'Age']
# 0.6329985562739313 :  ['SibSp', 'split_Pclass_2', 'Parch']
# 0.6835917393760592 :  ['SibSp', 'split_Pclass_2', 'Fare']
# 0.6689849978030256 :  ['SibSp', 'split_Pclass_2', 'split_Pclass_1']
# 0.6656142112861716 :  ['SibSp', 'split_Pclass_2', 'split_Pclass_3']
# 0.7901010608248069 :  ['SibSp', 'split_Pclass_2', 'split_sex_female']
# 0.7901010608248069 :  ['SibSp', 'split_Pclass_2', 'split_sex_male']
# 0.6374992153662671 :  ['SibSp', 'split_Pclass_2', 'is_child']
# 0.6723118448308328 :  ['SibSp', 'split_Pclass_3', 'Age']
# 0.6532421065846463 :  ['SibSp', 'split_Pclass_3', 'Parch']
# 0.6656330424957629 :  ['SibSp', 'split_Pclass_3', 'Fare']
# 0.6689849978030256 :  ['SibSp', 'split_Pclass_3', 'split_Pclass_1']
# 0.6656142112861716 :  ['SibSp', 'split_Pclass_3', 'split_Pclass_2']
# 0.7990898248697508 :  ['SibSp', 'split_Pclass_3', 'split_sex_female']
# 0.7990898248697508 :  ['SibSp', 'split_Pclass_3', 'split_sex_male']
# 0.6723620613897432 :  ['SibSp', 'split_Pclass_3', 'is_child']
# 0.7889837423890528 :  ['SibSp', 'split_sex_female', 'Age']
# 0.7889837423890528 :  ['SibSp', 'split_sex_female', 'Parch']
# 0.7912372104701525 :  ['SibSp', 'split_sex_female', 'Fare']
# 0.7945954428472789 :  ['SibSp', 'split_sex_female', 'split_Pclass_1']
# 0.7901010608248069 :  ['SibSp', 'split_sex_female', 'split_Pclass_2']
# 0.7990898248697508 :  ['SibSp', 'split_sex_female', 'split_Pclass_3']
# 0.7889837423890528 :  ['SibSp', 'split_sex_female', 'split_sex_male']
# 0.803577929822359 :  ['SibSp', 'split_sex_female', 'is_child']
# 0.7889837423890528 :  ['SibSp', 'split_sex_male', 'Age']
# 0.7889837423890528 :  ['SibSp', 'split_sex_male', 'Parch']
# 0.7912372104701525 :  ['SibSp', 'split_sex_male', 'Fare']
# 0.7945954428472789 :  ['SibSp', 'split_sex_male', 'split_Pclass_1']
# 0.7901010608248069 :  ['SibSp', 'split_sex_male', 'split_Pclass_2']
# 0.7990898248697508 :  ['SibSp', 'split_sex_male', 'split_Pclass_3']
# 0.7889837423890528 :  ['SibSp', 'split_sex_male', 'split_sex_female']
# 0.803577929822359 :  ['SibSp', 'split_sex_male', 'is_child']
# 0.6363756198606489 :  ['SibSp', 'is_child', 'Age']
# 0.6307701964722867 :  ['SibSp', 'is_child', 'Parch']
# 0.7038039043374553 :  ['SibSp', 'is_child', 'Fare']
# 0.6993095223149834 :  ['SibSp', 'is_child', 'split_Pclass_1']
# 0.6374992153662671 :  ['SibSp', 'is_child', 'split_Pclass_2']
# 0.6723620613897432 :  ['SibSp', 'is_child', 'split_Pclass_3']
# 0.803577929822359 :  ['SibSp', 'is_child', 'split_sex_female']
# 0.803577929822359 :  ['SibSp', 'is_child', 'split_sex_male']
# 0.636375619860649 :  ['Parch', 'Age', 'SibSp']
# 0.6633670202749355 :  ['Parch', 'Age', 'Fare']
# 0.6891971627644216 :  ['Parch', 'Age', 'split_Pclass_1']
# 0.6318875149080408 :  ['Parch', 'Age', 'split_Pclass_2']
# 0.679047140794677 :  ['Parch', 'Age', 'split_Pclass_3']
# 0.7867365513778168 :  ['Parch', 'Age', 'split_sex_female']
# 0.7867365513778168 :  ['Parch', 'Age', 'split_sex_male']
# 0.6307639194024229 :  ['Parch', 'Age', 'is_child']
# 0.636375619860649 :  ['Parch', 'SibSp', 'Age']
# 0.6746092524009792 :  ['Parch', 'SibSp', 'Fare']
# 0.6689912748728892 :  ['Parch', 'SibSp', 'split_Pclass_1']
# 0.6329985562739313 :  ['Parch', 'SibSp', 'split_Pclass_2']
# 0.6532421065846463 :  ['Parch', 'SibSp', 'split_Pclass_3']
# 0.7889837423890528 :  ['Parch', 'SibSp', 'split_sex_female']
# 0.7889837423890528 :  ['Parch', 'SibSp', 'split_sex_male']
# 0.6307701964722867 :  ['Parch', 'SibSp', 'is_child']
# 0.6633670202749355 :  ['Parch', 'Fare', 'Age']
# 0.6746092524009792 :  ['Parch', 'Fare', 'SibSp']
# 0.6813445483648233 :  ['Parch', 'Fare', 'split_Pclass_1']
# 0.6802146757893415 :  ['Parch', 'Fare', 'split_Pclass_2']
# 0.6824618668005775 :  ['Parch', 'Fare', 'split_Pclass_3']
# 0.7822547234950725 :  ['Parch', 'Fare', 'split_sex_female']
# 0.7822547234950725 :  ['Parch', 'Fare', 'split_sex_male']
# 0.6892097169041491 :  ['Parch', 'Fare', 'is_child']
# 0.6891971627644216 :  ['Parch', 'split_Pclass_1', 'Age']
# 0.6689912748728892 :  ['Parch', 'split_Pclass_1', 'SibSp']
# 0.6813445483648233 :  ['Parch', 'split_Pclass_1', 'Fare']
# 0.7004331178206014 :  ['Parch', 'split_Pclass_1', 'split_Pclass_2']
# 0.7037913501977278 :  ['Parch', 'split_Pclass_1', 'split_Pclass_3']
# 0.7867428284476807 :  ['Parch', 'split_Pclass_1', 'split_sex_female']
# 0.7867428284476807 :  ['Parch', 'split_Pclass_1', 'split_sex_male']
# 0.6970623313037475 :  ['Parch', 'split_Pclass_1', 'is_child']
# 0.6318875149080408 :  ['Parch', 'split_Pclass_2', 'Age']
# 0.6329985562739313 :  ['Parch', 'split_Pclass_2', 'SibSp']
# 0.6802146757893415 :  ['Parch', 'split_Pclass_2', 'Fare']
# 0.7004331178206014 :  ['Parch', 'split_Pclass_2', 'split_Pclass_1']
# 0.7037913501977278 :  ['Parch', 'split_Pclass_2', 'split_Pclass_3']
# 0.7867365513778168 :  ['Parch', 'split_Pclass_2', 'split_sex_female']
# 0.7867365513778168 :  ['Parch', 'split_Pclass_2', 'split_sex_male']
# 0.6375054924361309 :  ['Parch', 'split_Pclass_2', 'is_child']
# 0.679047140794677 :  ['Parch', 'split_Pclass_3', 'Age']
# 0.6532421065846463 :  ['Parch', 'split_Pclass_3', 'SibSp']
# 0.6824618668005775 :  ['Parch', 'split_Pclass_3', 'Fare']
# 0.7037913501977278 :  ['Parch', 'split_Pclass_3', 'split_Pclass_1']
# 0.7037913501977278 :  ['Parch', 'split_Pclass_3', 'split_Pclass_2']
# 0.7878601468834349 :  ['Parch', 'split_Pclass_3', 'split_sex_female']
# 0.7878601468834349 :  ['Parch', 'split_Pclass_3', 'split_sex_male']
# 0.6689912748728893 :  ['Parch', 'split_Pclass_3', 'is_child']
# 0.7867365513778168 :  ['Parch', 'split_sex_female', 'Age']
# 0.7889837423890528 :  ['Parch', 'split_sex_female', 'SibSp']
# 0.7822547234950725 :  ['Parch', 'split_sex_female', 'Fare']
# 0.7867428284476807 :  ['Parch', 'split_sex_female', 'split_Pclass_1']
# 0.7867365513778168 :  ['Parch', 'split_sex_female', 'split_Pclass_2']
# 0.7878601468834349 :  ['Parch', 'split_sex_female', 'split_Pclass_3']
# 0.7867365513778168 :  ['Parch', 'split_sex_female', 'split_sex_male']
# 0.7889837423890528 :  ['Parch', 'split_sex_female', 'is_child']
# 0.7867365513778168 :  ['Parch', 'split_sex_male', 'Age']
# 0.7889837423890528 :  ['Parch', 'split_sex_male', 'SibSp']
# 0.7822547234950725 :  ['Parch', 'split_sex_male', 'Fare']
# 0.7867428284476807 :  ['Parch', 'split_sex_male', 'split_Pclass_1']
# 0.7867365513778168 :  ['Parch', 'split_sex_male', 'split_Pclass_2']
# 0.7878601468834349 :  ['Parch', 'split_sex_male', 'split_Pclass_3']
# 0.7867365513778168 :  ['Parch', 'split_sex_male', 'split_sex_female']
# 0.7889837423890528 :  ['Parch', 'split_sex_male', 'is_child']
# 0.6307639194024229 :  ['Parch', 'is_child', 'Age']
# 0.6307701964722867 :  ['Parch', 'is_child', 'SibSp']
# 0.6892097169041491 :  ['Parch', 'is_child', 'Fare']
# 0.6970623313037475 :  ['Parch', 'is_child', 'split_Pclass_1']
# 0.6375054924361309 :  ['Parch', 'is_child', 'split_Pclass_2']
# 0.6689912748728893 :  ['Parch', 'is_child', 'split_Pclass_3']
# 0.7889837423890528 :  ['Parch', 'is_child', 'split_sex_female']
# 0.7889837423890528 :  ['Parch', 'is_child', 'split_sex_male']
# 0.6846839495323582 :  ['Fare', 'Age', 'SibSp']
# 0.6633670202749355 :  ['Fare', 'Age', 'Parch']
# 0.6790910802837236 :  ['Fare', 'Age', 'split_Pclass_1']
# 0.680202121649614 :  ['Fare', 'Age', 'split_Pclass_2']
# 0.6813068859456406 :  ['Fare', 'Age', 'split_Pclass_3']
# 0.7822547234950725 :  ['Fare', 'Age', 'split_sex_female']
# 0.7822547234950725 :  ['Fare', 'Age', 'split_sex_male']
# 0.6847027807419497 :  ['Fare', 'Age', 'is_child']
# 0.6846839495323582 :  ['Fare', 'SibSp', 'Age']
# 0.6746092524009792 :  ['Fare', 'SibSp', 'Parch']
# 0.6824681438704413 :  ['Fare', 'SibSp', 'split_Pclass_1']
# 0.6835917393760592 :  ['Fare', 'SibSp', 'split_Pclass_2']
# 0.6656330424957629 :  ['Fare', 'SibSp', 'split_Pclass_3']
# 0.7912372104701525 :  ['Fare', 'SibSp', 'split_sex_female']
# 0.7912372104701525 :  ['Fare', 'SibSp', 'split_sex_male']
# 0.7038039043374553 :  ['Fare', 'SibSp', 'is_child']
# 0.6633670202749355 :  ['Fare', 'Parch', 'Age']
# 0.6746092524009792 :  ['Fare', 'Parch', 'SibSp']
# 0.6813445483648233 :  ['Fare', 'Parch', 'split_Pclass_1']
# 0.6802146757893415 :  ['Fare', 'Parch', 'split_Pclass_2']
# 0.6824618668005775 :  ['Fare', 'Parch', 'split_Pclass_3']
# 0.7822547234950725 :  ['Fare', 'Parch', 'split_sex_female']
# 0.7822547234950725 :  ['Fare', 'Parch', 'split_sex_male']
# 0.6892097169041491 :  ['Fare', 'Parch', 'is_child']
# 0.6790910802837236 :  ['Fare', 'split_Pclass_1', 'Age']
# 0.6824681438704413 :  ['Fare', 'split_Pclass_1', 'SibSp']
# 0.6813445483648233 :  ['Fare', 'split_Pclass_1', 'Parch']
# 0.6824681438704412 :  ['Fare', 'split_Pclass_1', 'split_Pclass_2']
# 0.6835917393760592 :  ['Fare', 'split_Pclass_1', 'split_Pclass_3']
# 0.7833783190006904 :  ['Fare', 'split_Pclass_1', 'split_sex_female']
# 0.7833783190006904 :  ['Fare', 'split_Pclass_1', 'split_sex_male']
# 0.7038039043374553 :  ['Fare', 'split_Pclass_1', 'is_child']
# 0.680202121649614 :  ['Fare', 'split_Pclass_2', 'Age']
# 0.6835917393760592 :  ['Fare', 'split_Pclass_2', 'SibSp']
# 0.6802146757893415 :  ['Fare', 'split_Pclass_2', 'Parch']
# 0.6824681438704412 :  ['Fare', 'split_Pclass_2', 'split_Pclass_1']
# 0.6847216119515409 :  ['Fare', 'split_Pclass_2', 'split_Pclass_3']
# 0.7822547234950725 :  ['Fare', 'split_Pclass_2', 'split_sex_female']
# 0.7822547234950725 :  ['Fare', 'split_Pclass_2', 'split_sex_male']
# 0.6824681438704413 :  ['Fare', 'split_Pclass_2', 'is_child']
# 0.6813068859456406 :  ['Fare', 'split_Pclass_3', 'Age']
# 0.6656330424957629 :  ['Fare', 'split_Pclass_3', 'SibSp']
# 0.6824618668005775 :  ['Fare', 'split_Pclass_3', 'Parch']
# 0.6835917393760592 :  ['Fare', 'split_Pclass_3', 'split_Pclass_1']
# 0.6847216119515409 :  ['Fare', 'split_Pclass_3', 'split_Pclass_2']
# 0.7833783190006904 :  ['Fare', 'split_Pclass_3', 'split_sex_female']
# 0.7833783190006904 :  ['Fare', 'split_Pclass_3', 'split_sex_male']
# 0.6768689975519427 :  ['Fare', 'split_Pclass_3', 'is_child']
# 0.7822547234950725 :  ['Fare', 'split_sex_female', 'Age']
# 0.7912372104701525 :  ['Fare', 'split_sex_female', 'SibSp']
# 0.7822547234950725 :  ['Fare', 'split_sex_female', 'Parch']
# 0.7833783190006904 :  ['Fare', 'split_sex_female', 'split_Pclass_1']
# 0.7822547234950725 :  ['Fare', 'split_sex_female', 'split_Pclass_2']
# 0.7833783190006904 :  ['Fare', 'split_sex_female', 'split_Pclass_3']
# 0.7822547234950725 :  ['Fare', 'split_sex_female', 'split_sex_male']
# 0.7833845960705542 :  ['Fare', 'split_sex_female', 'is_child']
# 0.7822547234950725 :  ['Fare', 'split_sex_male', 'Age']
# 0.7912372104701525 :  ['Fare', 'split_sex_male', 'SibSp']
# 0.7822547234950725 :  ['Fare', 'split_sex_male', 'Parch']
# 0.7833783190006904 :  ['Fare', 'split_sex_male', 'split_Pclass_1']
# 0.7822547234950725 :  ['Fare', 'split_sex_male', 'split_Pclass_2']
# 0.7833783190006904 :  ['Fare', 'split_sex_male', 'split_Pclass_3']
# 0.7822547234950725 :  ['Fare', 'split_sex_male', 'split_sex_female']
# 0.7833845960705542 :  ['Fare', 'split_sex_male', 'is_child']
# 0.6847027807419497 :  ['Fare', 'is_child', 'Age']
# 0.7038039043374553 :  ['Fare', 'is_child', 'SibSp']
# 0.6892097169041491 :  ['Fare', 'is_child', 'Parch']
# 0.7038039043374553 :  ['Fare', 'is_child', 'split_Pclass_1']
# 0.6824681438704413 :  ['Fare', 'is_child', 'split_Pclass_2']
# 0.6768689975519427 :  ['Fare', 'is_child', 'split_Pclass_3']
# 0.7833845960705542 :  ['Fare', 'is_child', 'split_sex_female']
# 0.7833845960705542 :  ['Fare', 'is_child', 'split_sex_male']
# 0.6858389303872953 :  ['split_Pclass_1', 'Age', 'SibSp']
# 0.6891971627644216 :  ['split_Pclass_1', 'Age', 'Parch']
# 0.6790910802837236 :  ['split_Pclass_1', 'Age', 'Fare']
# 0.6869436946833218 :  ['split_Pclass_1', 'Age', 'split_Pclass_2']
# 0.6835791852363317 :  ['split_Pclass_1', 'Age', 'split_Pclass_3']
# 0.7822735547046639 :  ['split_Pclass_1', 'Age', 'split_sex_female']
# 0.7822735547046639 :  ['split_Pclass_1', 'Age', 'split_sex_male']
# 0.7026740317619734 :  ['split_Pclass_1', 'Age', 'is_child']
# 0.6858389303872953 :  ['split_Pclass_1', 'SibSp', 'Age']
# 0.6689912748728892 :  ['split_Pclass_1', 'SibSp', 'Parch']
# 0.6824681438704413 :  ['split_Pclass_1', 'SibSp', 'Fare']
# 0.6689849978030256 :  ['split_Pclass_1', 'SibSp', 'split_Pclass_2']
# 0.6689849978030256 :  ['split_Pclass_1', 'SibSp', 'split_Pclass_3']
# 0.7945954428472789 :  ['split_Pclass_1', 'SibSp', 'split_sex_female']
# 0.7945954428472789 :  ['split_Pclass_1', 'SibSp', 'split_sex_male']
# 0.6993095223149834 :  ['split_Pclass_1', 'SibSp', 'is_child']
# 0.6891971627644216 :  ['split_Pclass_1', 'Parch', 'Age']
# 0.6689912748728892 :  ['split_Pclass_1', 'Parch', 'SibSp']
# 0.6813445483648233 :  ['split_Pclass_1', 'Parch', 'Fare']
# 0.7004331178206014 :  ['split_Pclass_1', 'Parch', 'split_Pclass_2']
# 0.7037913501977278 :  ['split_Pclass_1', 'Parch', 'split_Pclass_3']
# 0.7867428284476807 :  ['split_Pclass_1', 'Parch', 'split_sex_female']
# 0.7867428284476807 :  ['split_Pclass_1', 'Parch', 'split_sex_male']
# 0.6970623313037475 :  ['split_Pclass_1', 'Parch', 'is_child']
# 0.6790910802837236 :  ['split_Pclass_1', 'Fare', 'Age']
# 0.6824681438704413 :  ['split_Pclass_1', 'Fare', 'SibSp']
# 0.6813445483648233 :  ['split_Pclass_1', 'Fare', 'Parch']
# 0.6824681438704412 :  ['split_Pclass_1', 'Fare', 'split_Pclass_2']
# 0.6835917393760592 :  ['split_Pclass_1', 'Fare', 'split_Pclass_3']
# 0.7833783190006904 :  ['split_Pclass_1', 'Fare', 'split_sex_female']
# 0.7833783190006904 :  ['split_Pclass_1', 'Fare', 'split_sex_male']
# 0.7038039043374553 :  ['split_Pclass_1', 'Fare', 'is_child']
# 0.6869436946833218 :  ['split_Pclass_1', 'split_Pclass_2', 'Age']
# 0.6689849978030256 :  ['split_Pclass_1', 'split_Pclass_2', 'SibSp']
# 0.7004331178206014 :  ['split_Pclass_1', 'split_Pclass_2', 'Parch']
# 0.6824681438704412 :  ['split_Pclass_1', 'split_Pclass_2', 'Fare']
# 0.6656142112861716 :  ['split_Pclass_1', 'split_Pclass_2', 'split_Pclass_3']
# 0.7867365513778168 :  ['split_Pclass_1', 'split_Pclass_2', 'split_sex_female']
# 0.7867365513778168 :  ['split_Pclass_1', 'split_Pclass_2', 'split_sex_male']
# 0.6981859268093654 :  ['split_Pclass_1', 'split_Pclass_2', 'is_child']
# 0.6835791852363317 :  ['split_Pclass_1', 'split_Pclass_3', 'Age']
# 0.6689849978030256 :  ['split_Pclass_1', 'split_Pclass_3', 'SibSp']
# 0.7037913501977278 :  ['split_Pclass_1', 'split_Pclass_3', 'Parch']
# 0.6835917393760592 :  ['split_Pclass_1', 'split_Pclass_3', 'Fare']
# 0.6656142112861716 :  ['split_Pclass_1', 'split_Pclass_3', 'split_Pclass_2']
# 0.7867365513778168 :  ['split_Pclass_1', 'split_Pclass_3', 'split_sex_female']
# 0.7867365513778168 :  ['split_Pclass_1', 'split_Pclass_3', 'split_sex_male']
# 0.6981859268093654 :  ['split_Pclass_1', 'split_Pclass_3', 'is_child']
# 0.7822735547046639 :  ['split_Pclass_1', 'split_sex_female', 'Age']
# 0.7945954428472789 :  ['split_Pclass_1', 'split_sex_female', 'SibSp']
# 0.7867428284476807 :  ['split_Pclass_1', 'split_sex_female', 'Parch']
# 0.7833783190006904 :  ['split_Pclass_1', 'split_sex_female', 'Fare']
# 0.7867365513778168 :  ['split_Pclass_1', 'split_sex_female', 'split_Pclass_2']
# 0.7867365513778168 :  ['split_Pclass_1', 'split_sex_female', 'split_Pclass_3']
# 0.7867365513778168 :  ['split_Pclass_1', 'split_sex_female', 'split_sex_male']
# 0.7889837423890528 :  ['split_Pclass_1', 'split_sex_female', 'is_child']
# 0.7822735547046639 :  ['split_Pclass_1', 'split_sex_male', 'Age']
# 0.7945954428472789 :  ['split_Pclass_1', 'split_sex_male', 'SibSp']
# 0.7867428284476807 :  ['split_Pclass_1', 'split_sex_male', 'Parch']
# 0.7833783190006904 :  ['split_Pclass_1', 'split_sex_male', 'Fare']
# 0.7867365513778168 :  ['split_Pclass_1', 'split_sex_male', 'split_Pclass_2']
# 0.7867365513778168 :  ['split_Pclass_1', 'split_sex_male', 'split_Pclass_3']
# 0.7867365513778168 :  ['split_Pclass_1', 'split_sex_male', 'split_sex_female']
# 0.7889837423890528 :  ['split_Pclass_1', 'split_sex_male', 'is_child']
# 0.7026740317619734 :  ['split_Pclass_1', 'is_child', 'Age']
# 0.6993095223149834 :  ['split_Pclass_1', 'is_child', 'SibSp']
# 0.6970623313037475 :  ['split_Pclass_1', 'is_child', 'Parch']
# 0.7038039043374553 :  ['split_Pclass_1', 'is_child', 'Fare']
# 0.6981859268093654 :  ['split_Pclass_1', 'is_child', 'split_Pclass_2']
# 0.6981859268093654 :  ['split_Pclass_1', 'is_child', 'split_Pclass_3']
# 0.7889837423890528 :  ['split_Pclass_1', 'is_child', 'split_sex_female']
# 0.7889837423890528 :  ['split_Pclass_1', 'is_child', 'split_sex_male']
# 0.6239972380892599 :  ['split_Pclass_2', 'Age', 'SibSp']
# 0.6318875149080408 :  ['split_Pclass_2', 'Age', 'Parch']
# 0.680202121649614 :  ['split_Pclass_2', 'Age', 'Fare']
# 0.6869436946833218 :  ['split_Pclass_2', 'Age', 'split_Pclass_1']
# 0.6779486535685143 :  ['split_Pclass_2', 'Age', 'split_Pclass_3']
# 0.7867365513778168 :  ['split_Pclass_2', 'Age', 'split_sex_female']
# 0.7867365513778168 :  ['split_Pclass_2', 'Age', 'split_sex_male']
# 0.6363756198606489 :  ['split_Pclass_2', 'Age', 'is_child']
# 0.6239972380892599 :  ['split_Pclass_2', 'SibSp', 'Age']
# 0.6329985562739313 :  ['split_Pclass_2', 'SibSp', 'Parch']
# 0.6835917393760592 :  ['split_Pclass_2', 'SibSp', 'Fare']
# 0.6689849978030256 :  ['split_Pclass_2', 'SibSp', 'split_Pclass_1']
# 0.6656142112861716 :  ['split_Pclass_2', 'SibSp', 'split_Pclass_3']
# 0.7901010608248069 :  ['split_Pclass_2', 'SibSp', 'split_sex_female']
# 0.7901010608248069 :  ['split_Pclass_2', 'SibSp', 'split_sex_male']
# 0.6374992153662671 :  ['split_Pclass_2', 'SibSp', 'is_child']
# 0.6318875149080408 :  ['split_Pclass_2', 'Parch', 'Age']
# 0.6329985562739313 :  ['split_Pclass_2', 'Parch', 'SibSp']
# 0.6802146757893415 :  ['split_Pclass_2', 'Parch', 'Fare']
# 0.7004331178206014 :  ['split_Pclass_2', 'Parch', 'split_Pclass_1']
# 0.7037913501977278 :  ['split_Pclass_2', 'Parch', 'split_Pclass_3']
# 0.7867365513778168 :  ['split_Pclass_2', 'Parch', 'split_sex_female']
# 0.7867365513778168 :  ['split_Pclass_2', 'Parch', 'split_sex_male']
# 0.6375054924361309 :  ['split_Pclass_2', 'Parch', 'is_child']
# 0.680202121649614 :  ['split_Pclass_2', 'Fare', 'Age']
# 0.6835917393760592 :  ['split_Pclass_2', 'Fare', 'SibSp']
# 0.6802146757893415 :  ['split_Pclass_2', 'Fare', 'Parch']
# 0.6824681438704412 :  ['split_Pclass_2', 'Fare', 'split_Pclass_1']
# 0.6847216119515409 :  ['split_Pclass_2', 'Fare', 'split_Pclass_3']
# 0.7822547234950725 :  ['split_Pclass_2', 'Fare', 'split_sex_female']
# 0.7822547234950725 :  ['split_Pclass_2', 'Fare', 'split_sex_male']
# 0.6824681438704413 :  ['split_Pclass_2', 'Fare', 'is_child']
# 0.6869436946833218 :  ['split_Pclass_2', 'split_Pclass_1', 'Age']
# 0.6689849978030256 :  ['split_Pclass_2', 'split_Pclass_1', 'SibSp']
# 0.7004331178206014 :  ['split_Pclass_2', 'split_Pclass_1', 'Parch']
# 0.6824681438704412 :  ['split_Pclass_2', 'split_Pclass_1', 'Fare']
# 0.6656142112861716 :  ['split_Pclass_2', 'split_Pclass_1', 'split_Pclass_3']
# 0.7867365513778168 :  ['split_Pclass_2', 'split_Pclass_1', 'split_sex_female']
# 0.7867365513778168 :  ['split_Pclass_2', 'split_Pclass_1', 'split_sex_male']
# 0.6981859268093654 :  ['split_Pclass_2', 'split_Pclass_1', 'is_child']
# 0.6779486535685143 :  ['split_Pclass_2', 'split_Pclass_3', 'Age']
# 0.6656142112861716 :  ['split_Pclass_2', 'split_Pclass_3', 'SibSp']
# 0.7037913501977278 :  ['split_Pclass_2', 'split_Pclass_3', 'Parch']
# 0.6847216119515409 :  ['split_Pclass_2', 'split_Pclass_3', 'Fare']
# 0.6656142112861716 :  ['split_Pclass_2', 'split_Pclass_3', 'split_Pclass_1']
# 0.7867365513778168 :  ['split_Pclass_2', 'split_Pclass_3', 'split_sex_female']
# 0.7867365513778168 :  ['split_Pclass_2', 'split_Pclass_3', 'split_sex_male']
# 0.6981859268093654 :  ['split_Pclass_2', 'split_Pclass_3', 'is_child']
# 0.7867365513778168 :  ['split_Pclass_2', 'split_sex_female', 'Age']
# 0.7901010608248069 :  ['split_Pclass_2', 'split_sex_female', 'SibSp']
# 0.7867365513778168 :  ['split_Pclass_2', 'split_sex_female', 'Parch']
# 0.7822547234950725 :  ['split_Pclass_2', 'split_sex_female', 'Fare']
# 0.7867365513778168 :  ['split_Pclass_2', 'split_sex_female', 'split_Pclass_1']
# 0.7867365513778168 :  ['split_Pclass_2', 'split_sex_female', 'split_Pclass_3']
# 0.7867365513778168 :  ['split_Pclass_2', 'split_sex_female', 'split_sex_male']
# 0.7912121021906974 :  ['split_Pclass_2', 'split_sex_female', 'is_child']
# 0.7867365513778168 :  ['split_Pclass_2', 'split_sex_male', 'Age']
# 0.7901010608248069 :  ['split_Pclass_2', 'split_sex_male', 'SibSp']
# 0.7867365513778168 :  ['split_Pclass_2', 'split_sex_male', 'Parch']
# 0.7822547234950725 :  ['split_Pclass_2', 'split_sex_male', 'Fare']
# 0.7867365513778168 :  ['split_Pclass_2', 'split_sex_male', 'split_Pclass_1']
# 0.7867365513778168 :  ['split_Pclass_2', 'split_sex_male', 'split_Pclass_3']
# 0.7867365513778168 :  ['split_Pclass_2', 'split_sex_male', 'split_sex_female']
# 0.7912121021906974 :  ['split_Pclass_2', 'split_sex_male', 'is_child']
# 0.6363756198606489 :  ['split_Pclass_2', 'is_child', 'Age']
# 0.6374992153662671 :  ['split_Pclass_2', 'is_child', 'SibSp']
# 0.6375054924361309 :  ['split_Pclass_2', 'is_child', 'Parch']
# 0.6824681438704413 :  ['split_Pclass_2', 'is_child', 'Fare']
# 0.6981859268093654 :  ['split_Pclass_2', 'is_child', 'split_Pclass_1']
# 0.6981859268093654 :  ['split_Pclass_2', 'is_child', 'split_Pclass_3']
# 0.7912121021906974 :  ['split_Pclass_2', 'is_child', 'split_sex_female']
# 0.7912121021906974 :  ['split_Pclass_2', 'is_child', 'split_sex_male']
# 0.6723118448308328 :  ['split_Pclass_3', 'Age', 'SibSp']
# 0.679047140794677 :  ['split_Pclass_3', 'Age', 'Parch']
# 0.6813068859456406 :  ['split_Pclass_3', 'Age', 'Fare']
# 0.6835791852363317 :  ['split_Pclass_3', 'Age', 'split_Pclass_1']
# 0.6779486535685143 :  ['split_Pclass_3', 'Age', 'split_Pclass_2']
# 0.8024355031071495 :  ['split_Pclass_3', 'Age', 'split_sex_female']
# 0.8024355031071495 :  ['split_Pclass_3', 'Age', 'split_sex_male']
# 0.6723306760404244 :  ['split_Pclass_3', 'Age', 'is_child']
# 0.6723118448308328 :  ['split_Pclass_3', 'SibSp', 'Age']
# 0.6532421065846463 :  ['split_Pclass_3', 'SibSp', 'Parch']
# 0.6656330424957629 :  ['split_Pclass_3', 'SibSp', 'Fare']
# 0.6689849978030256 :  ['split_Pclass_3', 'SibSp', 'split_Pclass_1']
# 0.6656142112861716 :  ['split_Pclass_3', 'SibSp', 'split_Pclass_2']
# 0.7990898248697508 :  ['split_Pclass_3', 'SibSp', 'split_sex_female']
# 0.7990898248697508 :  ['split_Pclass_3', 'SibSp', 'split_sex_male']
# 0.6723620613897432 :  ['split_Pclass_3', 'SibSp', 'is_child']
# 0.679047140794677 :  ['split_Pclass_3', 'Parch', 'Age']
# 0.6532421065846463 :  ['split_Pclass_3', 'Parch', 'SibSp']
# 0.6824618668005775 :  ['split_Pclass_3', 'Parch', 'Fare']
# 0.7037913501977278 :  ['split_Pclass_3', 'Parch', 'split_Pclass_1']
# 0.7037913501977278 :  ['split_Pclass_3', 'Parch', 'split_Pclass_2']
# 0.7878601468834349 :  ['split_Pclass_3', 'Parch', 'split_sex_female']
# 0.7878601468834349 :  ['split_Pclass_3', 'Parch', 'split_sex_male']
# 0.6689912748728893 :  ['split_Pclass_3', 'Parch', 'is_child']
# 0.6813068859456406 :  ['split_Pclass_3', 'Fare', 'Age']
# 0.6656330424957629 :  ['split_Pclass_3', 'Fare', 'SibSp']
# 0.6824618668005775 :  ['split_Pclass_3', 'Fare', 'Parch']
# 0.6835917393760592 :  ['split_Pclass_3', 'Fare', 'split_Pclass_1']
# 0.6847216119515409 :  ['split_Pclass_3', 'Fare', 'split_Pclass_2']
# 0.7833783190006904 :  ['split_Pclass_3', 'Fare', 'split_sex_female']
# 0.7833783190006904 :  ['split_Pclass_3', 'Fare', 'split_sex_male']
# 0.6768689975519427 :  ['split_Pclass_3', 'Fare', 'is_child']
# 0.6835791852363317 :  ['split_Pclass_3', 'split_Pclass_1', 'Age']
# 0.6689849978030256 :  ['split_Pclass_3', 'split_Pclass_1', 'SibSp']
# 0.7037913501977278 :  ['split_Pclass_3', 'split_Pclass_1', 'Parch']
# 0.6835917393760592 :  ['split_Pclass_3', 'split_Pclass_1', 'Fare']
# 0.6656142112861716 :  ['split_Pclass_3', 'split_Pclass_1', 'split_Pclass_2']
# 0.7867365513778168 :  ['split_Pclass_3', 'split_Pclass_1', 'split_sex_female']
# 0.7867365513778168 :  ['split_Pclass_3', 'split_Pclass_1', 'split_sex_male']
# 0.6981859268093654 :  ['split_Pclass_3', 'split_Pclass_1', 'is_child']
# 0.6779486535685143 :  ['split_Pclass_3', 'split_Pclass_2', 'Age']
# 0.6656142112861716 :  ['split_Pclass_3', 'split_Pclass_2', 'SibSp']
# 0.7037913501977278 :  ['split_Pclass_3', 'split_Pclass_2', 'Parch']
# 0.6847216119515409 :  ['split_Pclass_3', 'split_Pclass_2', 'Fare']
# 0.6656142112861716 :  ['split_Pclass_3', 'split_Pclass_2', 'split_Pclass_1']
# 0.7867365513778168 :  ['split_Pclass_3', 'split_Pclass_2', 'split_sex_female']
# 0.7867365513778168 :  ['split_Pclass_3', 'split_Pclass_2', 'split_sex_male']
# 0.6981859268093654 :  ['split_Pclass_3', 'split_Pclass_2', 'is_child']
# 0.8024355031071495 :  ['split_Pclass_3', 'split_sex_female', 'Age']
# 0.7990898248697508 :  ['split_Pclass_3', 'split_sex_female', 'SibSp']
# 0.7878601468834349 :  ['split_Pclass_3', 'split_sex_female', 'Parch']
# 0.7833783190006904 :  ['split_Pclass_3', 'split_sex_female', 'Fare']
# 0.7867365513778168 :  ['split_Pclass_3', 'split_sex_female', 'split_Pclass_1']
# 0.7867365513778168 :  ['split_Pclass_3', 'split_sex_female', 'split_Pclass_2']
# 0.7867365513778168 :  ['split_Pclass_3', 'split_sex_female', 'split_sex_male']
# 0.7979536752244052 :  ['split_Pclass_3', 'split_sex_female', 'is_child']
# 0.8024355031071495 :  ['split_Pclass_3', 'split_sex_male', 'Age']
# 0.7990898248697508 :  ['split_Pclass_3', 'split_sex_male', 'SibSp']
# 0.7878601468834349 :  ['split_Pclass_3', 'split_sex_male', 'Parch']
# 0.7833783190006904 :  ['split_Pclass_3', 'split_sex_male', 'Fare']
# 0.7867365513778168 :  ['split_Pclass_3', 'split_sex_male', 'split_Pclass_1']
# 0.7867365513778168 :  ['split_Pclass_3', 'split_sex_male', 'split_Pclass_2']
# 0.7867365513778168 :  ['split_Pclass_3', 'split_sex_male', 'split_sex_female']
# 0.7979536752244052 :  ['split_Pclass_3', 'split_sex_male', 'is_child']
# 0.6723306760404244 :  ['split_Pclass_3', 'is_child', 'Age']
# 0.6723620613897432 :  ['split_Pclass_3', 'is_child', 'SibSp']
# 0.6689912748728893 :  ['split_Pclass_3', 'is_child', 'Parch']
# 0.6768689975519427 :  ['split_Pclass_3', 'is_child', 'Fare']
# 0.6981859268093654 :  ['split_Pclass_3', 'is_child', 'split_Pclass_1']
# 0.6981859268093654 :  ['split_Pclass_3', 'is_child', 'split_Pclass_2']
# 0.7979536752244052 :  ['split_Pclass_3', 'is_child', 'split_sex_female']
# 0.7979536752244052 :  ['split_Pclass_3', 'is_child', 'split_sex_male']
# 0.7889837423890528 :  ['split_sex_female', 'Age', 'SibSp']
# 0.7867365513778168 :  ['split_sex_female', 'Age', 'Parch']
# 0.7822547234950725 :  ['split_sex_female', 'Age', 'Fare']
# 0.7822735547046639 :  ['split_sex_female', 'Age', 'split_Pclass_1']
# 0.7867365513778168 :  ['split_sex_female', 'Age', 'split_Pclass_2']
# 0.8024355031071495 :  ['split_sex_female', 'Age', 'split_Pclass_3']
# 0.7867365513778168 :  ['split_sex_female', 'Age', 'split_sex_male']
# 0.7867365513778168 :  ['split_sex_female', 'Age', 'is_child']
# 0.7889837423890528 :  ['split_sex_female', 'SibSp', 'Age']
# 0.7889837423890528 :  ['split_sex_female', 'SibSp', 'Parch']
# 0.7912372104701525 :  ['split_sex_female', 'SibSp', 'Fare']
# 0.7945954428472789 :  ['split_sex_female', 'SibSp', 'split_Pclass_1']
# 0.7901010608248069 :  ['split_sex_female', 'SibSp', 'split_Pclass_2']
# 0.7990898248697508 :  ['split_sex_female', 'SibSp', 'split_Pclass_3']
# 0.7889837423890528 :  ['split_sex_female', 'SibSp', 'split_sex_male']
# 0.803577929822359 :  ['split_sex_female', 'SibSp', 'is_child']
# 0.7867365513778168 :  ['split_sex_female', 'Parch', 'Age']
# 0.7889837423890528 :  ['split_sex_female', 'Parch', 'SibSp']
# 0.7822547234950725 :  ['split_sex_female', 'Parch', 'Fare']
# 0.7867428284476807 :  ['split_sex_female', 'Parch', 'split_Pclass_1']
# 0.7867365513778168 :  ['split_sex_female', 'Parch', 'split_Pclass_2']
# 0.7878601468834349 :  ['split_sex_female', 'Parch', 'split_Pclass_3']
# 0.7867365513778168 :  ['split_sex_female', 'Parch', 'split_sex_male']
# 0.7889837423890528 :  ['split_sex_female', 'Parch', 'is_child']
# 0.7822547234950725 :  ['split_sex_female', 'Fare', 'Age']
# 0.7912372104701525 :  ['split_sex_female', 'Fare', 'SibSp']
# 0.7822547234950725 :  ['split_sex_female', 'Fare', 'Parch']
# 0.7833783190006904 :  ['split_sex_female', 'Fare', 'split_Pclass_1']
# 0.7822547234950725 :  ['split_sex_female', 'Fare', 'split_Pclass_2']
# 0.7833783190006904 :  ['split_sex_female', 'Fare', 'split_Pclass_3']
# 0.7822547234950725 :  ['split_sex_female', 'Fare', 'split_sex_male']
# 0.7833845960705542 :  ['split_sex_female', 'Fare', 'is_child']
# 0.7822735547046639 :  ['split_sex_female', 'split_Pclass_1', 'Age']
# 0.7945954428472789 :  ['split_sex_female', 'split_Pclass_1', 'SibSp']
# 0.7867428284476807 :  ['split_sex_female', 'split_Pclass_1', 'Parch']
# 0.7833783190006904 :  ['split_sex_female', 'split_Pclass_1', 'Fare']
# 0.7867365513778168 :  ['split_sex_female', 'split_Pclass_1', 'split_Pclass_2']
# 0.7867365513778168 :  ['split_sex_female', 'split_Pclass_1', 'split_Pclass_3']
# 0.7867365513778168 :  ['split_sex_female', 'split_Pclass_1', 'split_sex_male']
# 0.7889837423890528 :  ['split_sex_female', 'split_Pclass_1', 'is_child']
# 0.7867365513778168 :  ['split_sex_female', 'split_Pclass_2', 'Age']
# 0.7901010608248069 :  ['split_sex_female', 'split_Pclass_2', 'SibSp']
# 0.7867365513778168 :  ['split_sex_female', 'split_Pclass_2', 'Parch']
# 0.7822547234950725 :  ['split_sex_female', 'split_Pclass_2', 'Fare']
# 0.7867365513778168 :  ['split_sex_female', 'split_Pclass_2', 'split_Pclass_1']
# 0.7867365513778168 :  ['split_sex_female', 'split_Pclass_2', 'split_Pclass_3']
# 0.7867365513778168 :  ['split_sex_female', 'split_Pclass_2', 'split_sex_male']
# 0.7912121021906974 :  ['split_sex_female', 'split_Pclass_2', 'is_child']
# 0.8024355031071495 :  ['split_sex_female', 'split_Pclass_3', 'Age']
# 0.7990898248697508 :  ['split_sex_female', 'split_Pclass_3', 'SibSp']
# 0.7878601468834349 :  ['split_sex_female', 'split_Pclass_3', 'Parch']
# 0.7833783190006904 :  ['split_sex_female', 'split_Pclass_3', 'Fare']
# 0.7867365513778168 :  ['split_sex_female', 'split_Pclass_3', 'split_Pclass_1']
# 0.7867365513778168 :  ['split_sex_female', 'split_Pclass_3', 'split_Pclass_2']
# 0.7867365513778168 :  ['split_sex_female', 'split_Pclass_3', 'split_sex_male']
# 0.7979536752244052 :  ['split_sex_female', 'split_Pclass_3', 'is_child']
# 0.7867365513778168 :  ['split_sex_female', 'split_sex_male', 'Age']
# 0.7889837423890528 :  ['split_sex_female', 'split_sex_male', 'SibSp']
# 0.7867365513778168 :  ['split_sex_female', 'split_sex_male', 'Parch']
# 0.7822547234950725 :  ['split_sex_female', 'split_sex_male', 'Fare']
# 0.7867365513778168 :  ['split_sex_female', 'split_sex_male', 'split_Pclass_1']
# 0.7867365513778168 :  ['split_sex_female', 'split_sex_male', 'split_Pclass_2']
# 0.7867365513778168 :  ['split_sex_female', 'split_sex_male', 'split_Pclass_3']
# 0.7867365513778168 :  ['split_sex_female', 'split_sex_male', 'is_child']
# 0.7867365513778168 :  ['split_sex_female', 'is_child', 'Age']
# 0.803577929822359 :  ['split_sex_female', 'is_child', 'SibSp']
# 0.7889837423890528 :  ['split_sex_female', 'is_child', 'Parch']
# 0.7833845960705542 :  ['split_sex_female', 'is_child', 'Fare']
# 0.7889837423890528 :  ['split_sex_female', 'is_child', 'split_Pclass_1']
# 0.7912121021906974 :  ['split_sex_female', 'is_child', 'split_Pclass_2']
# 0.7979536752244052 :  ['split_sex_female', 'is_child', 'split_Pclass_3']
# 0.7867365513778168 :  ['split_sex_female', 'is_child', 'split_sex_male']
# 0.7889837423890528 :  ['split_sex_male', 'Age', 'SibSp']
# 0.7867365513778168 :  ['split_sex_male', 'Age', 'Parch']
# 0.7822547234950725 :  ['split_sex_male', 'Age', 'Fare']
# 0.7822735547046639 :  ['split_sex_male', 'Age', 'split_Pclass_1']
# 0.7867365513778168 :  ['split_sex_male', 'Age', 'split_Pclass_2']
# 0.8024355031071495 :  ['split_sex_male', 'Age', 'split_Pclass_3']
# 0.7867365513778168 :  ['split_sex_male', 'Age', 'split_sex_female']
# 0.7867365513778168 :  ['split_sex_male', 'Age', 'is_child']
# 0.7889837423890528 :  ['split_sex_male', 'SibSp', 'Age']
# 0.7889837423890528 :  ['split_sex_male', 'SibSp', 'Parch']
# 0.7912372104701525 :  ['split_sex_male', 'SibSp', 'Fare']
# 0.7945954428472789 :  ['split_sex_male', 'SibSp', 'split_Pclass_1']
# 0.7901010608248069 :  ['split_sex_male', 'SibSp', 'split_Pclass_2']
# 0.7990898248697508 :  ['split_sex_male', 'SibSp', 'split_Pclass_3']
# 0.7889837423890528 :  ['split_sex_male', 'SibSp', 'split_sex_female']
# 0.803577929822359 :  ['split_sex_male', 'SibSp', 'is_child']
# 0.7867365513778168 :  ['split_sex_male', 'Parch', 'Age']
# 0.7889837423890528 :  ['split_sex_male', 'Parch', 'SibSp']
# 0.7822547234950725 :  ['split_sex_male', 'Parch', 'Fare']
# 0.7867428284476807 :  ['split_sex_male', 'Parch', 'split_Pclass_1']
# 0.7867365513778168 :  ['split_sex_male', 'Parch', 'split_Pclass_2']
# 0.7878601468834349 :  ['split_sex_male', 'Parch', 'split_Pclass_3']
# 0.7867365513778168 :  ['split_sex_male', 'Parch', 'split_sex_female']
# 0.7889837423890528 :  ['split_sex_male', 'Parch', 'is_child']
# 0.7822547234950725 :  ['split_sex_male', 'Fare', 'Age']
# 0.7912372104701525 :  ['split_sex_male', 'Fare', 'SibSp']
# 0.7822547234950725 :  ['split_sex_male', 'Fare', 'Parch']
# 0.7833783190006904 :  ['split_sex_male', 'Fare', 'split_Pclass_1']
# 0.7822547234950725 :  ['split_sex_male', 'Fare', 'split_Pclass_2']
# 0.7833783190006904 :  ['split_sex_male', 'Fare', 'split_Pclass_3']
# 0.7822547234950725 :  ['split_sex_male', 'Fare', 'split_sex_female']
# 0.7833845960705542 :  ['split_sex_male', 'Fare', 'is_child']
# 0.7822735547046639 :  ['split_sex_male', 'split_Pclass_1', 'Age']
# 0.7945954428472789 :  ['split_sex_male', 'split_Pclass_1', 'SibSp']
# 0.7867428284476807 :  ['split_sex_male', 'split_Pclass_1', 'Parch']
# 0.7833783190006904 :  ['split_sex_male', 'split_Pclass_1', 'Fare']
# 0.7867365513778168 :  ['split_sex_male', 'split_Pclass_1', 'split_Pclass_2']
# 0.7867365513778168 :  ['split_sex_male', 'split_Pclass_1', 'split_Pclass_3']
# 0.7867365513778168 :  ['split_sex_male', 'split_Pclass_1', 'split_sex_female']
# 0.7889837423890528 :  ['split_sex_male', 'split_Pclass_1', 'is_child']
# 0.7867365513778168 :  ['split_sex_male', 'split_Pclass_2', 'Age']
# 0.7901010608248069 :  ['split_sex_male', 'split_Pclass_2', 'SibSp']
# 0.7867365513778168 :  ['split_sex_male', 'split_Pclass_2', 'Parch']
# 0.7822547234950725 :  ['split_sex_male', 'split_Pclass_2', 'Fare']
# 0.7867365513778168 :  ['split_sex_male', 'split_Pclass_2', 'split_Pclass_1']
# 0.7867365513778168 :  ['split_sex_male', 'split_Pclass_2', 'split_Pclass_3']
# 0.7867365513778168 :  ['split_sex_male', 'split_Pclass_2', 'split_sex_female']
# 0.7912121021906974 :  ['split_sex_male', 'split_Pclass_2', 'is_child']
# 0.8024355031071495 :  ['split_sex_male', 'split_Pclass_3', 'Age']
# 0.7990898248697508 :  ['split_sex_male', 'split_Pclass_3', 'SibSp']
# 0.7878601468834349 :  ['split_sex_male', 'split_Pclass_3', 'Parch']
# 0.7833783190006904 :  ['split_sex_male', 'split_Pclass_3', 'Fare']
# 0.7867365513778168 :  ['split_sex_male', 'split_Pclass_3', 'split_Pclass_1']
# 0.7867365513778168 :  ['split_sex_male', 'split_Pclass_3', 'split_Pclass_2']
# 0.7867365513778168 :  ['split_sex_male', 'split_Pclass_3', 'split_sex_female']
# 0.7979536752244052 :  ['split_sex_male', 'split_Pclass_3', 'is_child']
# 0.7867365513778168 :  ['split_sex_male', 'split_sex_female', 'Age']
# 0.7889837423890528 :  ['split_sex_male', 'split_sex_female', 'SibSp']
# 0.7867365513778168 :  ['split_sex_male', 'split_sex_female', 'Parch']
# 0.7822547234950725 :  ['split_sex_male', 'split_sex_female', 'Fare']
# 0.7867365513778168 :  ['split_sex_male', 'split_sex_female', 'split_Pclass_1']
# 0.7867365513778168 :  ['split_sex_male', 'split_sex_female', 'split_Pclass_2']
# 0.7867365513778168 :  ['split_sex_male', 'split_sex_female', 'split_Pclass_3']
# 0.7867365513778168 :  ['split_sex_male', 'split_sex_female', 'is_child']
# 0.7867365513778168 :  ['split_sex_male', 'is_child', 'Age']
# 0.803577929822359 :  ['split_sex_male', 'is_child', 'SibSp']
# 0.7889837423890528 :  ['split_sex_male', 'is_child', 'Parch']
# 0.7833845960705542 :  ['split_sex_male', 'is_child', 'Fare']
# 0.7889837423890528 :  ['split_sex_male', 'is_child', 'split_Pclass_1']
# 0.7912121021906974 :  ['split_sex_male', 'is_child', 'split_Pclass_2']
# 0.7979536752244052 :  ['split_sex_male', 'is_child', 'split_Pclass_3']
# 0.7867365513778168 :  ['split_sex_male', 'is_child', 'split_sex_female']
# 0.6363756198606489 :  ['is_child', 'Age', 'SibSp']
# 0.6307639194024229 :  ['is_child', 'Age', 'Parch']
# 0.6847027807419497 :  ['is_child', 'Age', 'Fare']
# 0.7026740317619734 :  ['is_child', 'Age', 'split_Pclass_1']
# 0.6363756198606489 :  ['is_child', 'Age', 'split_Pclass_2']
# 0.6723306760404244 :  ['is_child', 'Age', 'split_Pclass_3']
# 0.7867365513778168 :  ['is_child', 'Age', 'split_sex_female']
# 0.7867365513778168 :  ['is_child', 'Age', 'split_sex_male']
# 0.6363756198606489 :  ['is_child', 'SibSp', 'Age']
# 0.6307701964722867 :  ['is_child', 'SibSp', 'Parch']
# 0.7038039043374553 :  ['is_child', 'SibSp', 'Fare']
# 0.6993095223149834 :  ['is_child', 'SibSp', 'split_Pclass_1']
# 0.6374992153662671 :  ['is_child', 'SibSp', 'split_Pclass_2']
# 0.6723620613897432 :  ['is_child', 'SibSp', 'split_Pclass_3']
# 0.803577929822359 :  ['is_child', 'SibSp', 'split_sex_female']
# 0.803577929822359 :  ['is_child', 'SibSp', 'split_sex_male']
# 0.6307639194024229 :  ['is_child', 'Parch', 'Age']
# 0.6307701964722867 :  ['is_child', 'Parch', 'SibSp']
# 0.6892097169041491 :  ['is_child', 'Parch', 'Fare']
# 0.6970623313037475 :  ['is_child', 'Parch', 'split_Pclass_1']
# 0.6375054924361309 :  ['is_child', 'Parch', 'split_Pclass_2']
# 0.6689912748728893 :  ['is_child', 'Parch', 'split_Pclass_3']
# 0.7889837423890528 :  ['is_child', 'Parch', 'split_sex_female']
# 0.7889837423890528 :  ['is_child', 'Parch', 'split_sex_male']
# 0.6847027807419497 :  ['is_child', 'Fare', 'Age']
# 0.7038039043374553 :  ['is_child', 'Fare', 'SibSp']
# ...
# 0.6981859268093654 :  ['is_child', 'split_Pclass_2', 'split_Pclass_1', 'split_Pclass_3']
# 0.7945828887075513 :  ['is_child', 'split_Pclass_2', 'split_Pclass_1', 'split_sex_female']
# 0.7945828887075513 :  ['is_child', 'split_Pclass_2', 'split_Pclass_1', 'split_sex_male']
# 0.6959324587282657 :  ['is_child', 'split_Pclass_2', 'split_Pclass_3', 'Age']
# 0.7026803088318373 :  ['is_child', 'split_Pclass_2', 'split_Pclass_3', 'SibSp']
# 0.7026865859017011 :  ['is_child', 'split_Pclass_2', 'split_Pclass_3', 'Parch']
# 0.700445671960329 :  ['is_child', 'split_Pclass_2', 'split_Pclass_3', 'Fare']
# 0.6981859268093654 :  ['is_child', 'split_Pclass_2', 'split_Pclass_3', 'split_Pclass_1']
# 0.7945828887075513 :  ['is_child', 'split_Pclass_2', 'split_Pclass_3', 'split_sex_female']
# 0.7945828887075513 :  ['is_child', 'split_Pclass_2', 'split_Pclass_3', 'split_sex_male']
# 0.788977465319189 :  ['is_child', 'split_Pclass_2', 'split_sex_female', 'Age']
# 0.8024543343167408 :  ['is_child', 'split_Pclass_2', 'split_sex_female', 'SibSp']
# 0.7923419747661791 :  ['is_child', 'split_Pclass_2', 'split_sex_female', 'Parch']
# 0.7889774653191889 :  ['is_child', 'split_Pclass_2', 'split_sex_female', 'Fare']
# 0.7945828887075513 :  ['is_child', 'split_Pclass_2', 'split_sex_female', 'split_Pclass_1']
# 0.7945828887075513 :  ['is_child', 'split_Pclass_2', 'split_sex_female', 'split_Pclass_3']
# 0.7912121021906974 :  ['is_child', 'split_Pclass_2', 'split_sex_female', 'split_sex_male']
# 0.788977465319189 :  ['is_child', 'split_Pclass_2', 'split_sex_male', 'Age']
# 0.8024543343167408 :  ['is_child', 'split_Pclass_2', 'split_sex_male', 'SibSp']
# 0.7923419747661791 :  ['is_child', 'split_Pclass_2', 'split_sex_male', 'Parch']
# 0.7889774653191889 :  ['is_child', 'split_Pclass_2', 'split_sex_male', 'Fare']
# 0.7945828887075513 :  ['is_child', 'split_Pclass_2', 'split_sex_male', 'split_Pclass_1']
# 0.7945828887075513 :  ['is_child', 'split_Pclass_2', 'split_sex_male', 'split_Pclass_3']
# 0.7912121021906974 :  ['is_child', 'split_Pclass_2', 'split_sex_male', 'split_sex_female']
# 0.6790659720042684 :  ['is_child', 'split_Pclass_3', 'Age', 'SibSp']
# 0.666725252652062 :  ['is_child', 'split_Pclass_3', 'Age', 'Parch']
# 0.6835917393760592 :  ['is_child', 'split_Pclass_3', 'Age', 'Fare']
# 0.7015504362563556 :  ['is_child', 'split_Pclass_3', 'Age', 'split_Pclass_1']
# 0.6959324587282657 :  ['is_child', 'split_Pclass_3', 'Age', 'split_Pclass_2']
# 0.8035590986127674 :  ['is_child', 'split_Pclass_3', 'Age', 'split_sex_female']
# 0.8035590986127674 :  ['is_child', 'split_Pclass_3', 'Age', 'split_sex_male']
# 0.6790659720042684 :  ['is_child', 'split_Pclass_3', 'SibSp', 'Age']
# 0.6509886385035466 :  ['is_child', 'split_Pclass_3', 'SibSp', 'Parch']
# 0.6959575670077208 :  ['is_child', 'split_Pclass_3', 'SibSp', 'Fare']
# 0.7026803088318373 :  ['is_child', 'split_Pclass_3', 'SibSp', 'split_Pclass_1']
# 0.7026803088318373 :  ['is_child', 'split_Pclass_3', 'SibSp', 'split_Pclass_2']
# 0.8103006716464753 :  ['is_child', 'split_Pclass_3', 'SibSp', 'split_sex_female']
# 0.8103006716464753 :  ['is_child', 'split_Pclass_3', 'SibSp', 'split_sex_male']
# 0.666725252652062 :  ['is_child', 'split_Pclass_3', 'Parch', 'Age']
# 0.6509886385035466 :  ['is_child', 'split_Pclass_3', 'Parch', 'SibSp']
# 0.6768689975519427 :  ['is_child', 'split_Pclass_3', 'Parch', 'Fare']
# 0.7015629903960832 :  ['is_child', 'split_Pclass_3', 'Parch', 'split_Pclass_1']
# 0.7026865859017011 :  ['is_child', 'split_Pclass_3', 'Parch', 'split_Pclass_2']
# 0.8103069487163392 :  ['is_child', 'split_Pclass_3', 'Parch', 'split_sex_female']
# 0.8103069487163392 :  ['is_child', 'split_Pclass_3', 'Parch', 'split_sex_male']
# 0.6835917393760592 :  ['is_child', 'split_Pclass_3', 'Fare', 'Age']
# 0.6959575670077208 :  ['is_child', 'split_Pclass_3', 'Fare', 'SibSp']
# 0.6768689975519427 :  ['is_child', 'split_Pclass_3', 'Fare', 'Parch']
# 0.695951289937857 :  ['is_child', 'split_Pclass_3', 'Fare', 'split_Pclass_1']
# 0.700445671960329 :  ['is_child', 'split_Pclass_3', 'Fare', 'split_Pclass_2']
# 0.7945954428472788 :  ['is_child', 'split_Pclass_3', 'Fare', 'split_sex_female']
# 0.7945954428472788 :  ['is_child', 'split_Pclass_3', 'Fare', 'split_sex_male']
# 0.7015504362563556 :  ['is_child', 'split_Pclass_3', 'split_Pclass_1', 'Age']
# 0.7026803088318373 :  ['is_child', 'split_Pclass_3', 'split_Pclass_1', 'SibSp']
# 0.7015629903960832 :  ['is_child', 'split_Pclass_3', 'split_Pclass_1', 'Parch']
# 0.695951289937857 :  ['is_child', 'split_Pclass_3', 'split_Pclass_1', 'Fare']
# 0.6981859268093654 :  ['is_child', 'split_Pclass_3', 'split_Pclass_1', 'split_Pclass_2']
# 0.7945828887075513 :  ['is_child', 'split_Pclass_3', 'split_Pclass_1', 'split_sex_female']
# 0.7945828887075513 :  ['is_child', 'split_Pclass_3', 'split_Pclass_1', 'split_sex_male']
# 0.6959324587282657 :  ['is_child', 'split_Pclass_3', 'split_Pclass_2', 'Age']
# 0.7026803088318373 :  ['is_child', 'split_Pclass_3', 'split_Pclass_2', 'SibSp']
# 0.7026865859017011 :  ['is_child', 'split_Pclass_3', 'split_Pclass_2', 'Parch']
# 0.700445671960329 :  ['is_child', 'split_Pclass_3', 'split_Pclass_2', 'Fare']
# 0.6981859268093654 :  ['is_child', 'split_Pclass_3', 'split_Pclass_2', 'split_Pclass_1']
# 0.7945828887075513 :  ['is_child', 'split_Pclass_3', 'split_Pclass_2', 'split_sex_female']
# 0.7945828887075513 :  ['is_child', 'split_Pclass_3', 'split_Pclass_2', 'split_sex_male']
# 0.8035590986127674 :  ['is_child', 'split_Pclass_3', 'split_sex_female', 'Age']
# 0.8103006716464753 :  ['is_child', 'split_Pclass_3', 'split_sex_female', 'SibSp']
# 0.8103069487163392 :  ['is_child', 'split_Pclass_3', 'split_sex_female', 'Parch']
# 0.7945954428472788 :  ['is_child', 'split_Pclass_3', 'split_sex_female', 'Fare']
# 0.7945828887075513 :  ['is_child', 'split_Pclass_3', 'split_sex_female', 'split_Pclass_1']
# 0.7945828887075513 :  ['is_child', 'split_Pclass_3', 'split_sex_female', 'split_Pclass_2']
# 0.7979536752244052 :  ['is_child', 'split_Pclass_3', 'split_sex_female', 'split_sex_male']
# 0.8035590986127674 :  ['is_child', 'split_Pclass_3', 'split_sex_male', 'Age']
# 0.8103006716464753 :  ['is_child', 'split_Pclass_3', 'split_sex_male', 'SibSp']
# 0.8103069487163392 :  ['is_child', 'split_Pclass_3', 'split_sex_male', 'Parch']
# 0.7945954428472788 :  ['is_child', 'split_Pclass_3', 'split_sex_male', 'Fare']
# 0.7945828887075513 :  ['is_child', 'split_Pclass_3', 'split_sex_male', 'split_Pclass_1']
# 0.7945828887075513 :  ['is_child', 'split_Pclass_3', 'split_sex_male', 'split_Pclass_2']
# 0.7979536752244052 :  ['is_child', 'split_Pclass_3', 'split_sex_male', 'split_sex_female']
# 0.7957190383528967 :  ['is_child', 'split_sex_female', 'Age', 'SibSp']
# 0.7878664239532986 :  ['is_child', 'split_sex_female', 'Age', 'Parch']
# 0.7833845960705542 :  ['is_child', 'split_sex_female', 'Age', 'Fare']
# 0.7867428284476806 :  ['is_child', 'split_sex_female', 'Age', 'split_Pclass_1']
# 0.788977465319189 :  ['is_child', 'split_sex_female', 'Age', 'split_Pclass_2']
# 0.8035590986127674 :  ['is_child', 'split_sex_female', 'Age', 'split_Pclass_3']
# 0.7867365513778168 :  ['is_child', 'split_sex_female', 'Age', 'split_sex_male']
# 0.7957190383528967 :  ['is_child', 'split_sex_female', 'SibSp', 'Age']
# 0.7979662293641328 :  ['is_child', 'split_sex_female', 'SibSp', 'Parch']
# 0.7945954428472789 :  ['is_child', 'split_sex_female', 'SibSp', 'Fare']
# 0.797966229364133 :  ['is_child', 'split_sex_female', 'SibSp', 'split_Pclass_1']
# 0.8024543343167408 :  ['is_child', 'split_sex_female', 'SibSp', 'split_Pclass_2']
# 0.8103006716464753 :  ['is_child', 'split_sex_female', 'SibSp', 'split_Pclass_3']
# 0.803577929822359 :  ['is_child', 'split_sex_female', 'SibSp', 'split_sex_male']
# 0.7878664239532986 :  ['is_child', 'split_sex_female', 'Parch', 'Age']
# 0.7979662293641328 :  ['is_child', 'split_sex_female', 'Parch', 'SibSp']
# 0.7833908731404181 :  ['is_child', 'split_sex_female', 'Parch', 'Fare']
# 0.7923545289059067 :  ['is_child', 'split_sex_female', 'Parch', 'split_Pclass_1']
# 0.7923419747661791 :  ['is_child', 'split_sex_female', 'Parch', 'split_Pclass_2']
# 0.8103069487163392 :  ['is_child', 'split_sex_female', 'Parch', 'split_Pclass_3']
# 0.7889837423890528 :  ['is_child', 'split_sex_female', 'Parch', 'split_sex_male']
# 0.7833845960705542 :  ['is_child', 'split_sex_female', 'Fare', 'Age']
# 0.7945954428472789 :  ['is_child', 'split_sex_female', 'Fare', 'SibSp']
# 0.7833908731404181 :  ['is_child', 'split_sex_female', 'Fare', 'Parch']
# 0.7856255100119265 :  ['is_child', 'split_sex_female', 'Fare', 'split_Pclass_1']
# 0.7889774653191889 :  ['is_child', 'split_sex_female', 'Fare', 'split_Pclass_2']
# 0.7945954428472788 :  ['is_child', 'split_sex_female', 'Fare', 'split_Pclass_3']
# 0.7833845960705542 :  ['is_child', 'split_sex_female', 'Fare', 'split_sex_male']
# 0.7867428284476806 :  ['is_child', 'split_sex_female', 'split_Pclass_1', 'Age']
# 0.797966229364133 :  ['is_child', 'split_sex_female', 'split_Pclass_1', 'SibSp']
# 0.7923545289059067 :  ['is_child', 'split_sex_female', 'split_Pclass_1', 'Parch']
# 0.7856255100119265 :  ['is_child', 'split_sex_female', 'split_Pclass_1', 'Fare']
# 0.7945828887075513 :  ['is_child', 'split_sex_female', 'split_Pclass_1', 'split_Pclass_2']
# 0.7945828887075513 :  ['is_child', 'split_sex_female', 'split_Pclass_1', 'split_Pclass_3']
# 0.7889837423890528 :  ['is_child', 'split_sex_female', 'split_Pclass_1', 'split_sex_male']
# 0.788977465319189 :  ['is_child', 'split_sex_female', 'split_Pclass_2', 'Age']
# 0.8024543343167408 :  ['is_child', 'split_sex_female', 'split_Pclass_2', 'SibSp']
# 0.7923419747661791 :  ['is_child', 'split_sex_female', 'split_Pclass_2', 'Parch']
# 0.7889774653191889 :  ['is_child', 'split_sex_female', 'split_Pclass_2', 'Fare']
# 0.7945828887075513 :  ['is_child', 'split_sex_female', 'split_Pclass_2', 'split_Pclass_1']
# 0.7945828887075513 :  ['is_child', 'split_sex_female', 'split_Pclass_2', 'split_Pclass_3']
# 0.7912121021906974 :  ['is_child', 'split_sex_female', 'split_Pclass_2', 'split_sex_male']
# 0.8035590986127674 :  ['is_child', 'split_sex_female', 'split_Pclass_3', 'Age']
# 0.8103006716464753 :  ['is_child', 'split_sex_female', 'split_Pclass_3', 'SibSp']
# 0.8103069487163392 :  ['is_child', 'split_sex_female', 'split_Pclass_3', 'Parch']
# 0.7945954428472788 :  ['is_child', 'split_sex_female', 'split_Pclass_3', 'Fare']
# 0.7945828887075513 :  ['is_child', 'split_sex_female', 'split_Pclass_3', 'split_Pclass_1']
# 0.7945828887075513 :  ['is_child', 'split_sex_female', 'split_Pclass_3', 'split_Pclass_2']
# 0.7979536752244052 :  ['is_child', 'split_sex_female', 'split_Pclass_3', 'split_sex_male']
# 0.7867365513778168 :  ['is_child', 'split_sex_female', 'split_sex_male', 'Age']
# 0.803577929822359 :  ['is_child', 'split_sex_female', 'split_sex_male', 'SibSp']
# 0.7889837423890528 :  ['is_child', 'split_sex_female', 'split_sex_male', 'Parch']
# 0.7833845960705542 :  ['is_child', 'split_sex_female', 'split_sex_male', 'Fare']
# 0.7889837423890528 :  ['is_child', 'split_sex_female', 'split_sex_male', 'split_Pclass_1']
# 0.7912121021906974 :  ['is_child', 'split_sex_female', 'split_sex_male', 'split_Pclass_2']
# 0.7979536752244052 :  ['is_child', 'split_sex_female', 'split_sex_male', 'split_Pclass_3']
# 0.7957190383528967 :  ['is_child', 'split_sex_male', 'Age', 'SibSp']
# 0.7878664239532986 :  ['is_child', 'split_sex_male', 'Age', 'Parch']
# 0.7833845960705542 :  ['is_child', 'split_sex_male', 'Age', 'Fare']
# 0.7867428284476806 :  ['is_child', 'split_sex_male', 'Age', 'split_Pclass_1']
# 0.788977465319189 :  ['is_child', 'split_sex_male', 'Age', 'split_Pclass_2']
# 0.8035590986127674 :  ['is_child', 'split_sex_male', 'Age', 'split_Pclass_3']
# 0.7867365513778168 :  ['is_child', 'split_sex_male', 'Age', 'split_sex_female']
# 0.7957190383528967 :  ['is_child', 'split_sex_male', 'SibSp', 'Age']
# 0.7979662293641328 :  ['is_child', 'split_sex_male', 'SibSp', 'Parch']
# 0.7945954428472789 :  ['is_child', 'split_sex_male', 'SibSp', 'Fare']
# 0.797966229364133 :  ['is_child', 'split_sex_male', 'SibSp', 'split_Pclass_1']
# 0.8024543343167408 :  ['is_child', 'split_sex_male', 'SibSp', 'split_Pclass_2']
# 0.8103006716464753 :  ['is_child', 'split_sex_male', 'SibSp', 'split_Pclass_3']
# 0.803577929822359 :  ['is_child', 'split_sex_male', 'SibSp', 'split_sex_female']
# 0.7878664239532986 :  ['is_child', 'split_sex_male', 'Parch', 'Age']
# 0.7979662293641328 :  ['is_child', 'split_sex_male', 'Parch', 'SibSp']
# 0.7833908731404181 :  ['is_child', 'split_sex_male', 'Parch', 'Fare']
# 0.7923545289059067 :  ['is_child', 'split_sex_male', 'Parch', 'split_Pclass_1']
# 0.7923419747661791 :  ['is_child', 'split_sex_male', 'Parch', 'split_Pclass_2']
# 0.8103069487163392 :  ['is_child', 'split_sex_male', 'Parch', 'split_Pclass_3']
# 0.7889837423890528 :  ['is_child', 'split_sex_male', 'Parch', 'split_sex_female']
# 0.7833845960705542 :  ['is_child', 'split_sex_male', 'Fare', 'Age']
# 0.7945954428472789 :  ['is_child', 'split_sex_male', 'Fare', 'SibSp']
# 0.7833908731404181 :  ['is_child', 'split_sex_male', 'Fare', 'Parch']
# 0.7856255100119265 :  ['is_child', 'split_sex_male', 'Fare', 'split_Pclass_1']
# 0.7889774653191889 :  ['is_child', 'split_sex_male', 'Fare', 'split_Pclass_2']
# 0.7945954428472788 :  ['is_child', 'split_sex_male', 'Fare', 'split_Pclass_3']
# 0.7833845960705542 :  ['is_child', 'split_sex_male', 'Fare', 'split_sex_female']
# 0.7867428284476806 :  ['is_child', 'split_sex_male', 'split_Pclass_1', 'Age']
# 0.797966229364133 :  ['is_child', 'split_sex_male', 'split_Pclass_1', 'SibSp']
# 0.7923545289059067 :  ['is_child', 'split_sex_male', 'split_Pclass_1', 'Parch']
# 0.7856255100119265 :  ['is_child', 'split_sex_male', 'split_Pclass_1', 'Fare']
# 0.7945828887075513 :  ['is_child', 'split_sex_male', 'split_Pclass_1', 'split_Pclass_2']
# 0.7945828887075513 :  ['is_child', 'split_sex_male', 'split_Pclass_1', 'split_Pclass_3']
# 0.7889837423890528 :  ['is_child', 'split_sex_male', 'split_Pclass_1', 'split_sex_female']
# 0.788977465319189 :  ['is_child', 'split_sex_male', 'split_Pclass_2', 'Age']
# 0.8024543343167408 :  ['is_child', 'split_sex_male', 'split_Pclass_2', 'SibSp']
# 0.7923419747661791 :  ['is_child', 'split_sex_male', 'split_Pclass_2', 'Parch']
# 0.7889774653191889 :  ['is_child', 'split_sex_male', 'split_Pclass_2', 'Fare']
# 0.7945828887075513 :  ['is_child', 'split_sex_male', 'split_Pclass_2', 'split_Pclass_1']
# 0.7945828887075513 :  ['is_child', 'split_sex_male', 'split_Pclass_2', 'split_Pclass_3']
# 0.7912121021906974 :  ['is_child', 'split_sex_male', 'split_Pclass_2', 'split_sex_female']
# 0.8035590986127674 :  ['is_child', 'split_sex_male', 'split_Pclass_3', 'Age']
# 0.8103006716464753 :  ['is_child', 'split_sex_male', 'split_Pclass_3', 'SibSp']
# 0.8103069487163392 :  ['is_child', 'split_sex_male', 'split_Pclass_3', 'Parch']
# 0.7945954428472788 :  ['is_child', 'split_sex_male', 'split_Pclass_3', 'Fare']
# 0.7945828887075513 :  ['is_child', 'split_sex_male', 'split_Pclass_3', 'split_Pclass_1']
# 0.7945828887075513 :  ['is_child', 'split_sex_male', 'split_Pclass_3', 'split_Pclass_2']
# 0.7979536752244052 :  ['is_child', 'split_sex_male', 'split_Pclass_3', 'split_sex_female']
# 0.7867365513778168 :  ['is_child', 'split_sex_male', 'split_sex_female', 'Age']
# 0.803577929822359 :  ['is_child', 'split_sex_male', 'split_sex_female', 'SibSp']
# 0.7889837423890528 :  ['is_child', 'split_sex_male', 'split_sex_female', 'Parch']
# 0.7833845960705542 :  ['is_child', 'split_sex_male', 'split_sex_female', 'Fare']
# 0.7889837423890528 :  ['is_child', 'split_sex_male', 'split_sex_female', 'split_Pclass_1']
# 0.7912121021906974 :  ['is_child', 'split_sex_male', 'split_sex_female', 'split_Pclass_2']
# 0.7979536752244052 :  ['is_child', 'split_sex_male', 'split_sex_female', 'split_Pclass_3']
# #####
# Avec 1 variable :  (0.7867365513778168, ['split_sex_female'])
# Avec 2 variables :  (0.7889837423890528, ['SibSp', 'split_sex_female'])
# Avec 3 variables :  (0.803577929822359, ['SibSp', 'split_sex_female', 'is_child'])
# Avec 4 variables :  (0.8103069487163392, ['Parch', 'split_Pclass_3', 'split_sex_female', 'is_child'])
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# - Pour 2 variables : il est préférable d'utiliser les propriétés suivantes : `['SibSp', 'split_sex_female']`
# - Pour 3 variables : il est préférable d'utiliser les propriétés suivantes : `['SibSp', 'split_sex_female', 'is_child']`
# - Pour 4 variables : il est préférable d'utiliser les propriétés suivantes : `['SibSp', 'split_sex_female', 'is_child']`

# %% [markdown]
# ### 2. Transformer les variables existantes en variable binaire (si ce n’est déjà le cas)

# %%
from sklearn.preprocessing import OneHotEncoder


def parse_model_4(X):
    X.Age = X.Age.fillna(np.nanmedian(X["Age"]))
    X["is_child"] = X.Age < 8
    class_dummies = pd.get_dummies(X["Pclass"], prefix="split_Pclass")
    X = X.join(class_dummies)

    class_dummies = pd.get_dummies(X["Sex"], prefix="split_sex")
    X = X.join(class_dummies)

    target = X.Survived

    keep = ['Parch', 'split_Pclass_3', 'split_sex_female', 'is_child']
    for col in X.columns:
        if col not in keep:
            del X[col]

    encoder = OneHotEncoder()

    datas = encoder.fit_transform(X)

    return pd.DataFrame(datas.toarray(), columns=encoder.get_feature_names()), target
# Out:
# /home/ludwig/Documents/ULCO/M2/IA - Verel/TPS/Tp2/venv/lib/python3.10/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# ### 3. Créer les variables produits x_i * x_j des variables binaires.

# %%
initial_width = X.shape[1]

X, y = parse_model_4(train.copy())

columnsList = X.columns

for i in columnsList:
    for j in columnsList:
        if i != j:
            vals = X[i] * X[j]

            X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
            pass


for i in columnsList:
    del X[i]
# Out:
# /home/ludwig/Documents/ULCO/M2/IA - Verel/TPS/Tp2/venv/lib/python3.10/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/3543955549.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)

# %% [markdown]
# ### 4. Calculer et comparer la régression logistique sur les nouvelles variables ainsi créées

# %%
lr = LogisticRegression(max_iter=1000000)
lr.fit(X, y)

compute_score(lr, X, y)
# Out:
# Index(['mul_x0_0_x0_1', 'mul_x0_0_x0_2', 'mul_x0_0_x0_3', 'mul_x0_0_x0_4',
#        'mul_x0_0_x0_5', 'mul_x0_0_x0_6', 'mul_x0_0_x1_False',
#        'mul_x0_0_x1_True', 'mul_x0_0_x2_0', 'mul_x0_0_x2_1',
#        ...
#        'mul_x3_1_x0_2', 'mul_x3_1_x0_3', 'mul_x3_1_x0_4', 'mul_x3_1_x0_5',
#        'mul_x3_1_x0_6', 'mul_x3_1_x1_False', 'mul_x3_1_x1_True',
#        'mul_x3_1_x2_0', 'mul_x3_1_x2_1', 'mul_x3_1_x3_0'],
#       dtype='object', length=156)
# 0.813709120582512

# %% [markdown]
# On remarque que l'on dispose d'un meilleur score avec celles nouvelles variables.

# %% [markdown]
# ### 5. Transformer les variables existantes en variable binaire dont les valeurs σi sont −1 ou +1

# %%
initial_width = X.shape[1]

X, y = parse_model_4(train.copy())

X = X.applymap(lambda x : x if x == 1 else -1)
# Out:
# /home/ludwig/Documents/ULCO/M2/IA - Verel/TPS/Tp2/venv/lib/python3.10/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
# /tmp/ipykernel_12212/1016626059.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)

# %% [markdown]
# ### 6. Créer les variables produits σ_i * σ_j des variables binaires

# %%
columnsList = X.columns

for i in columnsList:
    for j in columnsList:
        if i != j:
            vals = X[i] * X[j]

            X.insert(X.shape[1], "mul_" + i + "_" + j, vals, True)
            pass


for i in columnsList:
    del X[i]

# %% [markdown]
# ### 7. Calculer et comparer la régression logistique sur les nouvelles variables ainsi créées.

# %%
lr = LogisticRegression(max_iter=1000000)
lr.fit(X, y)

compute_score(lr, X, y)
# Out:
# 0.8238214801330738

# %% [markdown]
# On constate également une amélioration du score par rapport au modèle précédent.

# %% [markdown]
# # Partie 6 - Random Forest

# %% [markdown]
# ### 1. Calculer le modèle de régression random forest sans utiliser la variable is child.

# %%
def parse_model_5(X):
    X.Age = X.Age.fillna(np.nanmedian(X["Age"]))

    target = X.Survived

    class_dummies = pd.get_dummies(X["Pclass"], prefix="split_Pclass")
    X = X.join(class_dummies)

    class_dummies = pd.get_dummies(X["Sex"], prefix="split_sex")
    X = X.join(class_dummies)

    to_del = ["Name", "Cabin", "Embarked", "Survived", "Ticket", "Sex", "Pclass"]
    for col in to_del:
        del X[col]
    return X, target

from sklearn.ensemble import RandomForestClassifier

train = pd.read_csv('titanic_train.csv', sep=',')
train.set_index("PassengerId", inplace=True, drop=True)

X, y = parse_model_5(train.copy())
rf = RandomForestClassifier()
rf.fit(X, y)

compute_score(rf, X, y)
# Out:
# 0.8047705730964786

# %% [markdown]
# ### 2. Comment est mesuré l’importance d’une variable dans le modèle random forest ?

# %% [markdown]
# Random Forest produit plein de petits arbres de classification sur une fraction aléatoire des données puis il les fait voter. De ce vote sont déduits l’ordre et l’importance des variables explicatives.
#
#
# Lors de la phase d'apprentissage, Random First construit plusieurs arbres de classification et utilise un critère de décorrélation entre ces arbres. Avec cette méthode, on veut diminuer la corrélation en n'augmentant pas la variance. POur cela on réalise des divisions sur les abres, puis on calcule l'i
#
#
# On utilise out-of-bag error, et plus précisément on détermine l'importance d'une propriété grâce à la moyenne de la différence dans out-bag error après et avant les permutations, et cela, sur tous les arbres.

# %% [markdown]
# ### 3. Tracer l’importance des variables :

# %%
def classifier_importance(X, clf):
    import pylab as pl
    importances = clf.feature_importances_
    indices = np.argsort(importances)[::-1]
    pl.title("Feature importances")
    for tree in clf.estimators_:
        pl.plot(range(X.shape[1]), tree.feature_importances_[indices], "r")
    pl.plot(range(X.shape[1]), importances[indices], "b")
    pl.show()
    for f in range(X.shape[1]):
        print("%d. feature : %s (%f)" %
            (f+1, X.columns[indices[f]], importances[indices[f]]))

# %%
rf = RandomForestClassifier()
rf.fit(X, y)
classifier_importance(X, rf)
# Out:
# 1. feature : Fare (0.273611)
# 2. feature : Age (0.263343)
# 3. feature : split_sex_male (0.169776)
# 4. feature : split_sex_female (0.121370)
# 5. feature : split_Pclass_3 (0.058368)
# 6. feature : SibSp (0.042742)
# 7. feature : Parch (0.033217)
# 8. feature : split_Pclass_1 (0.022734)
# 9. feature : split_Pclass_2 (0.014839)

# %% [markdown]
# ### 4. Calculer l’importance des variables par la méthode ”Permutation”.

# %%
from sklearn.inspection import permutation_importance

result = permutation_importance(
    rf, X, y, n_repeats=10, random_state=42, n_jobs=2
)

sorted_importances_idx = result.importances_mean.argsort()
importances = pd.DataFrame(
    result.importances[sorted_importances_idx].T,
    columns=X.columns[sorted_importances_idx],
)
ax = importances.plot.box(vert=False, whis=10)
ax.set_title("Permutation Importances")
ax.axvline(x=0, color="k", linestyle="--")
ax.set_xlabel("Decrease in accuracy score")
ax.figure.tight_layout()

# %% [markdown]
# ### 5. Interpréter l’importance des variables.

# %% [markdown]
# Grâce au graphique, on comprend que la variable Fare à une grande importance. Toute permutation avec cette variable entrainera une forte baisse du score de la précision. On note le même phénomène avec la variable Age.
# Alors que lors de permutations des variables  split_Pclass_2, split_Pclass_1 ou Parch, on note une faible variation du score de précision, de plus elles ont une faible importance dae le modèle.

# %% [markdown]
# # Partie 7 - Gradient Boosting

# %% [markdown]
# ### 1. Comparer les performances de la méthode gradient boosting avec random forest.

# %%
from sklearn.ensemble import GradientBoostingClassifier
rf = GradientBoostingClassifier()
rf.fit(X, y)

compute_score(rf, X, y)
# Out:
# 0.8237900947837549

# %% [markdown]
# On note que l'on obtient un meilleur score avec Gradient Boosting qu'avec Random forest.
# Random Forest = Constuit tous les abres puis répercuté les erreurs
# Gradient Boosting = arbre un a un => il répercute
# Cela s'explique que Gradient Boosting utilise l'erreur des arbres qui la construit avant pour la répercutér sur ceux qu'il va constuire par la suite.
